# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
adityajn105_flickr8k_path = kagglehub.dataset_download('adityajn105/flickr8k')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Streaming output truncated to the last 5000 lines.
# /kaggle/input/flickr8k/Images/2925242998_9e0db9b4a2.jpg
# /kaggle/input/flickr8k/Images/2969380952_9f1eb7f93b.jpg
# /kaggle/input/flickr8k/Images/444845904_a4531c811a.jpg
# /kaggle/input/flickr8k/Images/3355827928_c96c0c3e88.jpg
# /kaggle/input/flickr8k/Images/3150440350_b0f2a9e774.jpg
# /kaggle/input/flickr8k/Images/3613705104_46d854134e.jpg
# /kaggle/input/flickr8k/Images/3712742641_641282803e.jpg
# /kaggle/input/flickr8k/Images/2922512807_d382528a93.jpg
# /kaggle/input/flickr8k/Images/3323952123_deb50b0629.jpg
# /kaggle/input/flickr8k/Images/3144705706_391d7b77c7.jpg
# /kaggle/input/flickr8k/Images/3590653633_495de5f288.jpg
# /kaggle/input/flickr8k/Images/421730441_6b2267fd31.jpg
# /kaggle/input/flickr8k/Images/3647170476_0fd71a4c9f.jpg
# /kaggle/input/flickr8k/Images/2432061076_0955d52854.jpg
# /kaggle/input/flickr8k/Images/1798215547_ef7ad95be8.jpg
# /kaggle/input/flickr8k/Images/1262077938_8b9516c273.jpg
# /kaggle/input/flickr8k/Images/3480379024_545e8ec818.jpg
# /kaggle/input/flickr8k/Images/93922153_8d831f7f01.jpg
# /kaggle/input/flickr8k/Images/3670918456_68631d362a.jpg
# /kaggle/input/flickr8k/Images/3141613533_595723208d.jpg
# /kaggle/input/flickr8k/Images/3286045254_696c6b15bd.jpg
# /kaggle/input/flickr8k/Images/2380464803_a64f05bfa9.jpg
# /kaggle/input/flickr8k/Images/3340857141_85d97a7466.jpg
# /kaggle/input/flickr8k/Images/2107837987_ffecfc367a.jpg
# /kaggle/input/flickr8k/Images/3441511444_b031585b45.jpg
# /kaggle/input/flickr8k/Images/1112212364_0c48235fc2.jpg
# /kaggle/input/flickr8k/Images/3167365436_c379bda282.jpg
# /kaggle/input/flickr8k/Images/2238019823_79318d1f11.jpg
# /kaggle/input/flickr8k/Images/2845845721_d0bc113ff7.jpg
# /kaggle/input/flickr8k/Images/3593392955_a4125087f6.jpg
# /kaggle/input/flickr8k/Images/2977379863_2e8d7a104e.jpg
# /kaggle/input/flickr8k/Images/1251558317_4ef844b775.jpg
# /kaggle/input/flickr8k/Images/2073756099_7e02c0110c.jpg
# /kaggle/input/flickr8k/Images/3739833689_a0038545bd.jpg
# /kaggle/input/flickr8k/Images/3691670743_0ed111bcf3.jpg
# /kaggle/input/flickr8k/Images/3503689049_63212220be.jpg
# /kaggle/input/flickr8k/Images/2522540026_6ee8ab4c6a.jpg
# /kaggle/input/flickr8k/Images/413737417_b0a8b445e9.jpg
# /kaggle/input/flickr8k/Images/535399240_0714a6e950.jpg
# /kaggle/input/flickr8k/Images/2994205788_f8b3f2e840.jpg
# /kaggle/input/flickr8k/Images/2584957647_4f9235c150.jpg
# /kaggle/input/flickr8k/Images/3338217927_3c5cf3f7c6.jpg
# /kaggle/input/flickr8k/Images/3084011664_76d37c6559.jpg
# /kaggle/input/flickr8k/Images/2891617125_f939f604c7.jpg
# /kaggle/input/flickr8k/Images/3482974845_db4f16befa.jpg
# /kaggle/input/flickr8k/Images/3470008804_0ca36a7a09.jpg
# /kaggle/input/flickr8k/Images/3478176372_7c510a0cef.jpg
# /kaggle/input/flickr8k/Images/1490670858_e122df2560.jpg
# /kaggle/input/flickr8k/Images/3259002340_707ce96858.jpg
# /kaggle/input/flickr8k/Images/2857473929_4f52662c30.jpg
# /kaggle/input/flickr8k/Images/3043904009_3b5e0412cd.jpg
# /kaggle/input/flickr8k/Images/2649406158_ded6be38de.jpg
# /kaggle/input/flickr8k/Images/3716244806_97d5a1fb61.jpg
# /kaggle/input/flickr8k/Images/2060031241_a3ae7a06bb.jpg
# /kaggle/input/flickr8k/Images/3111402233_6285bcba7a.jpg
# /kaggle/input/flickr8k/Images/3239480519_22540b5016.jpg
# /kaggle/input/flickr8k/Images/2500354186_0836309cc9.jpg
# /kaggle/input/flickr8k/Images/2632381125_de32bdfdf6.jpg
# /kaggle/input/flickr8k/Images/2410562803_56ec09f41c.jpg
# /kaggle/input/flickr8k/Images/3323498985_fd9d2803fd.jpg
# /kaggle/input/flickr8k/Images/2114126343_a0f74ff63b.jpg
# /kaggle/input/flickr8k/Images/3053415073_5b667230ed.jpg
# /kaggle/input/flickr8k/Images/3424851862_0f51c42922.jpg
# /kaggle/input/flickr8k/Images/3583321426_f373c52161.jpg
# /kaggle/input/flickr8k/Images/2834103050_512e5b330a.jpg
# /kaggle/input/flickr8k/Images/3643684688_2f7157b23d.jpg
# /kaggle/input/flickr8k/Images/2322593776_e6aaf69e80.jpg
# /kaggle/input/flickr8k/Images/2976155358_b4dd4407cf.jpg
# /kaggle/input/flickr8k/Images/772403830_08b72c7da9.jpg
# /kaggle/input/flickr8k/Images/359837950_9e22ffe6c2.jpg
# /kaggle/input/flickr8k/Images/442220883_ff3d6e507f.jpg
# /kaggle/input/flickr8k/Images/2698487246_e827404cac.jpg
# /kaggle/input/flickr8k/Images/3443853670_6c79fcfcb2.jpg
# /kaggle/input/flickr8k/Images/3463523977_f2ed231585.jpg
# /kaggle/input/flickr8k/Images/2510197716_fddca0ac75.jpg
# /kaggle/input/flickr8k/Images/457945610_1a23b9ced0.jpg
# /kaggle/input/flickr8k/Images/2435166927_28b8130660.jpg
# /kaggle/input/flickr8k/Images/3404978479_8a81843e17.jpg
# /kaggle/input/flickr8k/Images/3425887426_bf60b8afa3.jpg
# /kaggle/input/flickr8k/Images/2261346505_302c67951d.jpg
# /kaggle/input/flickr8k/Images/3468023754_8a07d4c56e.jpg
# /kaggle/input/flickr8k/Images/289616152_012a9f16c6.jpg
# /kaggle/input/flickr8k/Images/3654338683_13b2f95a9a.jpg
# /kaggle/input/flickr8k/Images/224026428_0165164ceb.jpg
# /kaggle/input/flickr8k/Images/514431934_9cf78f05a9.jpg
# /kaggle/input/flickr8k/Images/2458269558_277012780d.jpg
# /kaggle/input/flickr8k/Images/3051341320_1d0166e775.jpg
# /kaggle/input/flickr8k/Images/2428086758_bce4733f7e.jpg
# /kaggle/input/flickr8k/Images/535529555_583d89b7f2.jpg
# /kaggle/input/flickr8k/Images/3019923691_3b3c5a4766.jpg
# /kaggle/input/flickr8k/Images/3046286572_d2050ab0d9.jpg
# /kaggle/input/flickr8k/Images/3149804151_1cc8d10783.jpg
# /kaggle/input/flickr8k/Images/2949497756_be8e58e6bd.jpg
# /kaggle/input/flickr8k/Images/241347204_007d83e252.jpg
# /kaggle/input/flickr8k/Images/3286017638_c688c83e3d.jpg
# /kaggle/input/flickr8k/Images/3398276602_c7d106c34f.jpg
# /kaggle/input/flickr8k/Images/3695517194_2a6b604cb2.jpg
# /kaggle/input/flickr8k/Images/2301867590_98c0ecb0cb.jpg
# /kaggle/input/flickr8k/Images/2868136205_3cf679208d.jpg
# /kaggle/input/flickr8k/Images/267164457_2e8b4d30aa.jpg
# /kaggle/input/flickr8k/Images/199463720_329a802206.jpg
# /kaggle/input/flickr8k/Images/189740668_0b045f1ff2.jpg
# /kaggle/input/flickr8k/Images/2773400732_5b65a25857.jpg
# /kaggle/input/flickr8k/Images/3504158556_1d410c8ff7.jpg
# /kaggle/input/flickr8k/Images/1088767354_2acee738cf.jpg
# /kaggle/input/flickr8k/Images/1445123245_c7b9db0e0c.jpg
# /kaggle/input/flickr8k/Images/3710468717_c051d96a5f.jpg
# /kaggle/input/flickr8k/Images/3220009216_10f088185e.jpg
# /kaggle/input/flickr8k/Images/1387461595_2fe6925f73.jpg
# /kaggle/input/flickr8k/Images/2075041394_0b3ea1822d.jpg
# /kaggle/input/flickr8k/Images/317488612_70ac35493b.jpg
# /kaggle/input/flickr8k/Images/3136043366_b3f8607a0e.jpg
# /kaggle/input/flickr8k/Images/3262301835_9f1a49b80a.jpg
# /kaggle/input/flickr8k/Images/543326592_70bd4d8602.jpg
# /kaggle/input/flickr8k/Images/3669069522_555c97fbfb.jpg
# /kaggle/input/flickr8k/Images/610590753_cd69ce081a.jpg
# /kaggle/input/flickr8k/Images/2693425189_47740c22ed.jpg
# /kaggle/input/flickr8k/Images/3744832122_2f4febdff6.jpg
# /kaggle/input/flickr8k/Images/3341477531_4e37450f35.jpg
# /kaggle/input/flickr8k/Images/3618908551_7fd2de5710.jpg
# /kaggle/input/flickr8k/Images/3107889179_106d223345.jpg
# /kaggle/input/flickr8k/Images/2922973230_5a769ef92a.jpg
# /kaggle/input/flickr8k/Images/3126225245_96cd2c053f.jpg
# /kaggle/input/flickr8k/Images/1351764581_4d4fb1b40f.jpg
# /kaggle/input/flickr8k/Images/1117972841_2b9261f95f.jpg
# /kaggle/input/flickr8k/Images/2591603141_33d6397e0a.jpg
# /kaggle/input/flickr8k/Images/2890075175_4bd32b201a.jpg
# /kaggle/input/flickr8k/Images/166507476_9be5b9852a.jpg
# /kaggle/input/flickr8k/Images/3377570617_d2f2225a74.jpg
# /kaggle/input/flickr8k/Images/795081510_53fd17d101.jpg
# /kaggle/input/flickr8k/Images/3383545083_1d7c95b003.jpg
# /kaggle/input/flickr8k/Images/195962284_e57178054a.jpg
# /kaggle/input/flickr8k/Images/3457856049_2de173e818.jpg
# /kaggle/input/flickr8k/Images/405537503_f66ecc5073.jpg
# /kaggle/input/flickr8k/Images/515702827_be3c6ce857.jpg
# /kaggle/input/flickr8k/Images/2868575889_2c030aa8ae.jpg
# /kaggle/input/flickr8k/Images/3145967019_1a83ebf712.jpg
# /kaggle/input/flickr8k/Images/2992999413_018f48aabc.jpg
# /kaggle/input/flickr8k/Images/2649705487_4605e879e9.jpg
# /kaggle/input/flickr8k/Images/3110174991_a4b05f8a46.jpg
# /kaggle/input/flickr8k/Images/1773928579_5664a810dc.jpg
# /kaggle/input/flickr8k/Images/3474985382_26e1560338.jpg
# /kaggle/input/flickr8k/Images/2214847438_4993210d4c.jpg
# /kaggle/input/flickr8k/Images/2126950128_74a4882658.jpg
# /kaggle/input/flickr8k/Images/2041867793_552819a40b.jpg
# /kaggle/input/flickr8k/Images/445655284_c29e6d7323.jpg
# /kaggle/input/flickr8k/Images/3296226598_1c892c4351.jpg
# /kaggle/input/flickr8k/Images/3511062827_cd87871c67.jpg
# /kaggle/input/flickr8k/Images/233361142_d9d5f0cae9.jpg
# /kaggle/input/flickr8k/Images/3319405494_58dee86b21.jpg
# /kaggle/input/flickr8k/Images/3694071771_ce760db4c7.jpg
# /kaggle/input/flickr8k/Images/1354318519_2f9baed754.jpg
# /kaggle/input/flickr8k/Images/2667783499_3a4f38f636.jpg
# /kaggle/input/flickr8k/Images/2970183443_accd597e0a.jpg
# /kaggle/input/flickr8k/Images/3077781040_bc27778609.jpg
# /kaggle/input/flickr8k/Images/3420323191_d66e003264.jpg
# /kaggle/input/flickr8k/Images/3268407162_6274e0f74f.jpg
# /kaggle/input/flickr8k/Images/3677329561_fa3e1fdcf9.jpg
# /kaggle/input/flickr8k/Images/583087629_a09334e1fb.jpg
# /kaggle/input/flickr8k/Images/2004674713_2883e63c67.jpg
# /kaggle/input/flickr8k/Images/2274992140_bb9e868bb8.jpg
# /kaggle/input/flickr8k/Images/3533470072_87a5b595ba.jpg
# /kaggle/input/flickr8k/Images/1552065993_b4dcd2eadf.jpg
# /kaggle/input/flickr8k/Images/3440160917_4524cfd9f6.jpg
# /kaggle/input/flickr8k/Images/41999070_838089137e.jpg
# /kaggle/input/flickr8k/Images/3123770450_cedc16d162.jpg
# /kaggle/input/flickr8k/Images/1159574340_99ba8c3c59.jpg
# /kaggle/input/flickr8k/Images/224766705_b77996527f.jpg
# /kaggle/input/flickr8k/Images/3544803461_a418ca611e.jpg
# /kaggle/input/flickr8k/Images/2502782508_2c8211cd6b.jpg
# /kaggle/input/flickr8k/Images/3636126441_5617c89aaa.jpg
# /kaggle/input/flickr8k/Images/1465666502_de289b3b9c.jpg
# /kaggle/input/flickr8k/Images/276356412_dfa01c3c9e.jpg
# /kaggle/input/flickr8k/Images/2501968935_02f2cd8079.jpg
# /kaggle/input/flickr8k/Images/3459362347_c412ef9901.jpg
# /kaggle/input/flickr8k/Images/3497237366_366997495d.jpg
# /kaggle/input/flickr8k/Images/3708748633_e7e3cf4e84.jpg
# /kaggle/input/flickr8k/Images/3518126579_e70e0cbb2b.jpg
# /kaggle/input/flickr8k/Images/3577309234_c952c2af86.jpg
# /kaggle/input/flickr8k/Images/3456579559_b5c8927938.jpg
# /kaggle/input/flickr8k/Images/2980118787_2099de53ec.jpg
# /kaggle/input/flickr8k/Images/410413536_11f1127c46.jpg
# /kaggle/input/flickr8k/Images/1082379191_ec1e53f996.jpg
# /kaggle/input/flickr8k/Images/2176874361_2b4149010b.jpg
# /kaggle/input/flickr8k/Images/1473618073_7db56a5237.jpg
# /kaggle/input/flickr8k/Images/264928854_d9e61f3a8e.jpg
# /kaggle/input/flickr8k/Images/3453259666_9ecaa8bb4b.jpg
# /kaggle/input/flickr8k/Images/1572532018_64c030c974.jpg
# /kaggle/input/flickr8k/Images/491405109_798222cfd0.jpg
# /kaggle/input/flickr8k/Images/3640329164_20cb245fd5.jpg
# /kaggle/input/flickr8k/Images/3634785801_4b23184a06.jpg
# /kaggle/input/flickr8k/Images/2439813616_c9ac54cc9f.jpg
# /kaggle/input/flickr8k/Images/2519812011_f85c3b5cb5.jpg
# /kaggle/input/flickr8k/Images/2240539658_dea8db6e55.jpg
# /kaggle/input/flickr8k/Images/2672354635_3a03f76486.jpg
# /kaggle/input/flickr8k/Images/197924859_f6e39a7dfa.jpg
# /kaggle/input/flickr8k/Images/3677318686_b018862bb7.jpg
# /kaggle/input/flickr8k/Images/211295363_49010ca38d.jpg
# /kaggle/input/flickr8k/Images/2477623312_58e8e8c8af.jpg
# /kaggle/input/flickr8k/Images/3170551725_1276644eab.jpg
# /kaggle/input/flickr8k/Images/3057770908_3fd97f79f9.jpg
# /kaggle/input/flickr8k/Images/2297471897_3419605c16.jpg
# /kaggle/input/flickr8k/Images/2975253472_0f0c2dea70.jpg
# /kaggle/input/flickr8k/Images/3431671749_e8e3a449ac.jpg
# /kaggle/input/flickr8k/Images/3289893683_d4cc3ce208.jpg
# /kaggle/input/flickr8k/Images/1067180831_a59dc64344.jpg
# /kaggle/input/flickr8k/Images/3642220260_3aa8a52670.jpg
# /kaggle/input/flickr8k/Images/42637986_135a9786a6.jpg
# /kaggle/input/flickr8k/Images/2310126952_7dc86d88f6.jpg
# /kaggle/input/flickr8k/Images/1019604187_d087bf9a5f.jpg
# /kaggle/input/flickr8k/Images/3640870001_acbd1d5ceb.jpg
# /kaggle/input/flickr8k/Images/307321761_606fc91673.jpg
# /kaggle/input/flickr8k/Images/3578841731_f775cab089.jpg
# /kaggle/input/flickr8k/Images/2592019072_a6c0090da4.jpg
# /kaggle/input/flickr8k/Images/112178718_87270d9b4d.jpg
# /kaggle/input/flickr8k/Images/3634281981_d9cf1d1a33.jpg
# /kaggle/input/flickr8k/Images/3613242966_a1c63a0174.jpg
# /kaggle/input/flickr8k/Images/2481598514_05a65d1f72.jpg
# /kaggle/input/flickr8k/Images/3174228611_6cf9d2266b.jpg
# /kaggle/input/flickr8k/Images/263216826_acf868049c.jpg
# /kaggle/input/flickr8k/Images/3246804978_ea2c9e56f2.jpg
# /kaggle/input/flickr8k/Images/3600909823_ce72c26e66.jpg
# /kaggle/input/flickr8k/Images/2206403470_8c25aa3cf8.jpg
# /kaggle/input/flickr8k/Images/2999162229_80d17099b6.jpg
# /kaggle/input/flickr8k/Images/425088533_a460dc4617.jpg
# /kaggle/input/flickr8k/Images/3286111436_891ae7dab9.jpg
# /kaggle/input/flickr8k/Images/174466741_329a52b2fe.jpg
# /kaggle/input/flickr8k/Images/445148321_9f2f3ac711.jpg
# /kaggle/input/flickr8k/Images/3671777903_6fbf643980.jpg
# /kaggle/input/flickr8k/Images/241345522_c3c266a02a.jpg
# /kaggle/input/flickr8k/Images/2344898759_5674382bcd.jpg
# /kaggle/input/flickr8k/Images/3471571540_b4ab77f20d.jpg
# /kaggle/input/flickr8k/Images/3342272425_804316cb3d.jpg
# /kaggle/input/flickr8k/Images/3484842724_ef1124c87a.jpg
# /kaggle/input/flickr8k/Images/2864634088_d087494dff.jpg
# /kaggle/input/flickr8k/Images/2806710650_e201acd913.jpg
# /kaggle/input/flickr8k/Images/2358447641_10f1e9d21f.jpg
# /kaggle/input/flickr8k/Images/2933637854_984614e18b.jpg
# /kaggle/input/flickr8k/Images/3332248667_617606714b.jpg
# /kaggle/input/flickr8k/Images/3517466790_17c7753a1a.jpg
# /kaggle/input/flickr8k/Images/2330536645_2d36b516e1.jpg
# /kaggle/input/flickr8k/Images/3157744152_31ace8c9ed.jpg
# /kaggle/input/flickr8k/Images/3072782873_3278f3b3a7.jpg
# /kaggle/input/flickr8k/Images/3347798761_5c5260b000.jpg
# /kaggle/input/flickr8k/Images/3150742439_b8a352e1e0.jpg
# /kaggle/input/flickr8k/Images/3421177332_a05741cfa4.jpg
# /kaggle/input/flickr8k/Images/226531363_33ac01d931.jpg
# /kaggle/input/flickr8k/Images/760138567_762d9022d4.jpg
# /kaggle/input/flickr8k/Images/251792066_b5233b3d86.jpg
# /kaggle/input/flickr8k/Images/3349955993_a04aea97d8.jpg
# /kaggle/input/flickr8k/Images/3539840291_1c3eed701d.jpg
# /kaggle/input/flickr8k/Images/522486784_978021d537.jpg
# /kaggle/input/flickr8k/Images/2720985888_8f5920e8cf.jpg
# /kaggle/input/flickr8k/Images/3442272060_f9155194c2.jpg
# /kaggle/input/flickr8k/Images/2707244524_d57120d74a.jpg
# /kaggle/input/flickr8k/Images/3525453732_f74a38f111.jpg
# /kaggle/input/flickr8k/Images/2756636539_cc1eacbf4a.jpg
# /kaggle/input/flickr8k/Images/2630507245_bea4804288.jpg
# /kaggle/input/flickr8k/Images/3085667865_fa001816be.jpg
# /kaggle/input/flickr8k/Images/2216568822_84c295c3b0.jpg
# /kaggle/input/flickr8k/Images/412056525_191724b058.jpg
# /kaggle/input/flickr8k/Images/3716277216_c04002be81.jpg
# /kaggle/input/flickr8k/Images/3243591844_791cfa62eb.jpg
# /kaggle/input/flickr8k/Images/3253060519_55d98c208f.jpg
# /kaggle/input/flickr8k/Images/3474912569_7165dc1d06.jpg
# /kaggle/input/flickr8k/Images/346253487_687150ab04.jpg
# /kaggle/input/flickr8k/Images/2587017287_888c811b5a.jpg
# /kaggle/input/flickr8k/Images/501684722_0f20c4e704.jpg
# /kaggle/input/flickr8k/Images/2394919002_ed7527ff93.jpg
# /kaggle/input/flickr8k/Images/3212625256_685bc4de99.jpg
# /kaggle/input/flickr8k/Images/1396703063_e8c3687afe.jpg
# /kaggle/input/flickr8k/Images/3326086533_23a0a54a8e.jpg
# /kaggle/input/flickr8k/Images/2762702644_2aa3bf9680.jpg
# /kaggle/input/flickr8k/Images/3583293892_c96af8cd98.jpg
# /kaggle/input/flickr8k/Images/3372340429_91c4f4af30.jpg
# /kaggle/input/flickr8k/Images/3427540832_c882fded1d.jpg
# /kaggle/input/flickr8k/Images/3649224118_abe73c672c.jpg
# /kaggle/input/flickr8k/Images/3568065409_1c381aa854.jpg
# /kaggle/input/flickr8k/Images/2319175397_3e586cfaf8.jpg
# /kaggle/input/flickr8k/Images/3088074124_481139dc92.jpg
# /kaggle/input/flickr8k/Images/2978810122_183e60ff2d.jpg
# /kaggle/input/flickr8k/Images/2581066814_179d28f306.jpg
# /kaggle/input/flickr8k/Images/3589052481_059e5e2c37.jpg
# /kaggle/input/flickr8k/Images/3540155303_08225a4567.jpg
# /kaggle/input/flickr8k/Images/2480832276_fa55480ecb.jpg
# /kaggle/input/flickr8k/Images/3325157569_8084ab3293.jpg
# /kaggle/input/flickr8k/Images/302241178_a582c1b953.jpg
# /kaggle/input/flickr8k/Images/3533394378_1513ec90db.jpg
# /kaggle/input/flickr8k/Images/2606433181_f8f9d38579.jpg
# /kaggle/input/flickr8k/Images/2268115375_69884e958d.jpg
# /kaggle/input/flickr8k/Images/3359636318_39267812a0.jpg
# /kaggle/input/flickr8k/Images/2853407781_c9fea8eef4.jpg
# /kaggle/input/flickr8k/Images/3128856481_86e5df4160.jpg
# /kaggle/input/flickr8k/Images/3264678536_46601d25f0.jpg
# /kaggle/input/flickr8k/Images/2165461920_1a4144eb2b.jpg
# /kaggle/input/flickr8k/Images/3548191125_514f47e493.jpg
# /kaggle/input/flickr8k/Images/3566111626_9a35a7b2c0.jpg
# /kaggle/input/flickr8k/Images/3136674757_57406c305c.jpg
# /kaggle/input/flickr8k/Images/2192333873_2a0cbe849d.jpg
# /kaggle/input/flickr8k/Images/2943384009_c8cf749181.jpg
# /kaggle/input/flickr8k/Images/2628331789_c7f7d90e5d.jpg
# /kaggle/input/flickr8k/Images/2171154778_8189169336.jpg
# /kaggle/input/flickr8k/Images/3259229498_2b5708c0c6.jpg
# /kaggle/input/flickr8k/Images/444481722_690d0cadcf.jpg
# /kaggle/input/flickr8k/Images/3353962769_ba48691bc6.jpg
# /kaggle/input/flickr8k/Images/3699522388_2333f01f40.jpg
# /kaggle/input/flickr8k/Images/2252299132_14ca6e584b.jpg
# /kaggle/input/flickr8k/Images/464116251_1ac4bc91f8.jpg
# /kaggle/input/flickr8k/Images/3247423890_163f00a2cb.jpg
# /kaggle/input/flickr8k/Images/2887744223_029f2fd5fe.jpg
# /kaggle/input/flickr8k/Images/101654506_8eb26cfb60.jpg
# /kaggle/input/flickr8k/Images/3085973779_29f44fbdaa.jpg
# /kaggle/input/flickr8k/Images/370614351_98b8a166b9.jpg
# /kaggle/input/flickr8k/Images/2286270205_16038dec5a.jpg
# /kaggle/input/flickr8k/Images/3587781729_bd21ce7b11.jpg
# /kaggle/input/flickr8k/Images/380515798_c2abbf46b0.jpg
# /kaggle/input/flickr8k/Images/3421706363_a3e22a4908.jpg
# /kaggle/input/flickr8k/Images/3404906655_bc51c69c1e.jpg
# /kaggle/input/flickr8k/Images/1368383637_614646cc4a.jpg
# /kaggle/input/flickr8k/Images/2426215757_e008a91fcb.jpg
# /kaggle/input/flickr8k/Images/2346401538_f5e8da66fc.jpg
# /kaggle/input/flickr8k/Images/2085403342_a17b0654fe.jpg
# /kaggle/input/flickr8k/Images/3277162496_dff7eeb59e.jpg
# /kaggle/input/flickr8k/Images/388386075_9ac3a89ada.jpg
# /kaggle/input/flickr8k/Images/241374292_11e3198daa.jpg
# /kaggle/input/flickr8k/Images/561179884_8b6b925ef9.jpg
# /kaggle/input/flickr8k/Images/3553476195_fb3747d7c1.jpg
# /kaggle/input/flickr8k/Images/3516960094_87fb4889de.jpg
# /kaggle/input/flickr8k/Images/3242263536_a436f19257.jpg
# /kaggle/input/flickr8k/Images/3247168324_c45eaf734d.jpg
# /kaggle/input/flickr8k/Images/3348208268_6d97d951eb.jpg
# /kaggle/input/flickr8k/Images/3421928157_69a325366f.jpg
# /kaggle/input/flickr8k/Images/3573202338_f43dd22d28.jpg
# /kaggle/input/flickr8k/Images/2949762776_52ece64d28.jpg
# /kaggle/input/flickr8k/Images/3169591322_d0b6d0cd04.jpg
# /kaggle/input/flickr8k/Images/2907073768_08fd7bdf60.jpg
# /kaggle/input/flickr8k/Images/3337046794_296bd2c7e0.jpg
# /kaggle/input/flickr8k/Images/345284642_77dded0907.jpg
# /kaggle/input/flickr8k/Images/2881087519_ca0aa79b2b.jpg
# /kaggle/input/flickr8k/Images/3301021288_95935b7a74.jpg
# /kaggle/input/flickr8k/Images/2269795781_46a296aa21.jpg
# /kaggle/input/flickr8k/Images/911795495_342bb15b97.jpg
# /kaggle/input/flickr8k/Images/3105691757_817083b0a6.jpg
# /kaggle/input/flickr8k/Images/223299137_b0e81ac145.jpg
# /kaggle/input/flickr8k/Images/2218609886_892dcd6915.jpg
# /kaggle/input/flickr8k/Images/2775744946_1ab5d500a2.jpg
# /kaggle/input/flickr8k/Images/485312202_784508f2a9.jpg
# /kaggle/input/flickr8k/Images/416650559_cd08d3cd96.jpg
# /kaggle/input/flickr8k/Images/3756150099_50882fc029.jpg
# /kaggle/input/flickr8k/Images/3639704469_fe83e1c9b7.jpg
# /kaggle/input/flickr8k/Images/756521713_5d3da56a54.jpg
# /kaggle/input/flickr8k/Images/1332815795_8eea44375e.jpg
# /kaggle/input/flickr8k/Images/3556792157_d09d42bef7.jpg
# /kaggle/input/flickr8k/Images/2222559267_6fd31e3941.jpg
# /kaggle/input/flickr8k/Images/1436760519_8d6101a0ed.jpg
# /kaggle/input/flickr8k/Images/2398605966_1d0c9e6a20.jpg
# /kaggle/input/flickr8k/Images/3703413486_3c682732a0.jpg
# /kaggle/input/flickr8k/Images/3599568766_9e96def0ef.jpg
# /kaggle/input/flickr8k/Images/392976422_c8d0514bc3.jpg
# /kaggle/input/flickr8k/Images/494921598_af73bda568.jpg
# /kaggle/input/flickr8k/Images/2797188545_aeb26c54c0.jpg
# /kaggle/input/flickr8k/Images/2902661518_1513be3ea6.jpg
# /kaggle/input/flickr8k/Images/2980348138_91cc6f6d0f.jpg
# /kaggle/input/flickr8k/Images/3127888173_9a9a8ac3bd.jpg
# /kaggle/input/flickr8k/Images/3551170666_01df31412d.jpg
# /kaggle/input/flickr8k/Images/2870194345_0bcbac1aa5.jpg
# /kaggle/input/flickr8k/Images/541063419_a5f3672d59.jpg
# /kaggle/input/flickr8k/Images/3345025842_bc2082a509.jpg
# /kaggle/input/flickr8k/Images/3681056426_fbd6c0c92c.jpg
# /kaggle/input/flickr8k/Images/542317719_ed4dd95dc2.jpg
# /kaggle/input/flickr8k/Images/2180356743_b3a3c9a7f6.jpg
# /kaggle/input/flickr8k/Images/256283122_a4ef4a17cb.jpg
# /kaggle/input/flickr8k/Images/3126681108_f88128699c.jpg
# /kaggle/input/flickr8k/Images/3251234434_d01e25a50a.jpg
# /kaggle/input/flickr8k/Images/3248220732_0f173fc197.jpg
# /kaggle/input/flickr8k/Images/109260218_fca831f933.jpg
# /kaggle/input/flickr8k/Images/3606846822_28c40b933a.jpg
# /kaggle/input/flickr8k/Images/3124964754_2e8a98fb09.jpg
# /kaggle/input/flickr8k/Images/3450776690_38605c667d.jpg
# /kaggle/input/flickr8k/Images/489065557_0eb08889cd.jpg
# /kaggle/input/flickr8k/Images/2326730558_75c20e5033.jpg
# /kaggle/input/flickr8k/Images/3214381315_b54f5c9be4.jpg
# /kaggle/input/flickr8k/Images/2458862292_466a920ee2.jpg
# /kaggle/input/flickr8k/Images/2474047296_fd9179d438.jpg
# /kaggle/input/flickr8k/Images/3634400263_c6fcaa48e1.jpg
# /kaggle/input/flickr8k/Images/3593222804_c187808ac3.jpg
# /kaggle/input/flickr8k/Images/3616808182_fb4eaec778.jpg
# /kaggle/input/flickr8k/Images/448658518_eec0b648a6.jpg
# /kaggle/input/flickr8k/Images/408748500_e8dc8c0c4f.jpg
# /kaggle/input/flickr8k/Images/3456251289_c4ae31d817.jpg
# /kaggle/input/flickr8k/Images/3278189732_f750cb26b7.jpg
# /kaggle/input/flickr8k/Images/2208310655_a3d83080c5.jpg
# /kaggle/input/flickr8k/Images/3571039224_b34fa2f94c.jpg
# /kaggle/input/flickr8k/Images/3162442331_c9711857c6.jpg
# /kaggle/input/flickr8k/Images/2551344688_17a12a6948.jpg
# /kaggle/input/flickr8k/Images/3245504245_27931f5ec1.jpg
# /kaggle/input/flickr8k/Images/3501936223_6122a13d27.jpg
# /kaggle/input/flickr8k/Images/534313000_4ad39c7ee0.jpg
# /kaggle/input/flickr8k/Images/3207264553_8cd4dcde53.jpg
# /kaggle/input/flickr8k/Images/1962729184_6996e128e7.jpg
# /kaggle/input/flickr8k/Images/1122944218_8eb3607403.jpg
# /kaggle/input/flickr8k/Images/3295418287_5d590dac43.jpg
# /kaggle/input/flickr8k/Images/3717531382_e1e05e22c5.jpg
# /kaggle/input/flickr8k/Images/2801851082_8c3c480c0f.jpg
# /kaggle/input/flickr8k/Images/3677860841_3aa9d8036c.jpg
# /kaggle/input/flickr8k/Images/3211289105_e0360a9c7f.jpg
# /kaggle/input/flickr8k/Images/1716445442_9cf3528342.jpg
# /kaggle/input/flickr8k/Images/3174431688_ae84778db0.jpg
# /kaggle/input/flickr8k/Images/1426014905_da60d72957.jpg
# /kaggle/input/flickr8k/Images/2920305300_a5b1b2329a.jpg
# /kaggle/input/flickr8k/Images/3001612175_53567ffb58.jpg
# /kaggle/input/flickr8k/Images/423066487_07757b2b49.jpg
# /kaggle/input/flickr8k/Images/105342180_4d4a40b47f.jpg
# /kaggle/input/flickr8k/Images/2848266893_9693c66275.jpg
# /kaggle/input/flickr8k/Images/2248487956_2603f55ab9.jpg
# /kaggle/input/flickr8k/Images/232874193_c691df882d.jpg
# /kaggle/input/flickr8k/Images/2257798999_d9d1b9a45a.jpg
# /kaggle/input/flickr8k/Images/1439282131_3814d6ae04.jpg
# /kaggle/input/flickr8k/Images/3702607829_2b8b3e65ab.jpg
# /kaggle/input/flickr8k/Images/2535746605_8124bf4e4f.jpg
# /kaggle/input/flickr8k/Images/2372572028_53b76104a9.jpg
# /kaggle/input/flickr8k/Images/136644885_f7d2bbf546.jpg
# /kaggle/input/flickr8k/Images/3399798295_a452963365.jpg
# /kaggle/input/flickr8k/Images/2822891602_ff61df2ece.jpg
# /kaggle/input/flickr8k/Images/3759492488_592cd78ed1.jpg
# /kaggle/input/flickr8k/Images/3326273086_e09e845185.jpg
# /kaggle/input/flickr8k/Images/2299427360_422a3fb8b0.jpg
# /kaggle/input/flickr8k/Images/866841633_05d273b96d.jpg
# /kaggle/input/flickr8k/Images/1446053356_a924b4893f.jpg
# /kaggle/input/flickr8k/Images/3249891130_b241591e89.jpg
# /kaggle/input/flickr8k/Images/3640104986_5d8c9a9948.jpg
# /kaggle/input/flickr8k/Images/2981372647_2061278c60.jpg
# /kaggle/input/flickr8k/Images/3418504074_083f0bb68d.jpg
# /kaggle/input/flickr8k/Images/3380072636_4cd59385fd.jpg
# /kaggle/input/flickr8k/Images/2076865206_53918c820c.jpg
# /kaggle/input/flickr8k/Images/2192026581_b782d1355a.jpg
# /kaggle/input/flickr8k/Images/96399948_b86c61bfe6.jpg
# /kaggle/input/flickr8k/Images/3562169000_6aa7f1043d.jpg
# /kaggle/input/flickr8k/Images/3420338549_bd78d35243.jpg
# /kaggle/input/flickr8k/Images/3126724531_f483e1b92a.jpg
# /kaggle/input/flickr8k/Images/3211581957_df2f7e2236.jpg
# /kaggle/input/flickr8k/Images/1277185009_06478dd457.jpg
# /kaggle/input/flickr8k/Images/1835511273_790eaae6e6.jpg
# /kaggle/input/flickr8k/Images/3101378069_f8caa14c0a.jpg
# /kaggle/input/flickr8k/Images/3146232740_df3da0163b.jpg
# /kaggle/input/flickr8k/Images/466956209_2ffcea3941.jpg
# /kaggle/input/flickr8k/Images/2518853257_02f30e282e.jpg
# /kaggle/input/flickr8k/Images/241347760_d44c8d3a01.jpg
# /kaggle/input/flickr8k/Images/3046190891_05c6ecd9b6.jpg
# /kaggle/input/flickr8k/Images/3361210233_962d630ec5.jpg
# /kaggle/input/flickr8k/Images/2635908229_b9fc90d3fb.jpg
# /kaggle/input/flickr8k/Images/2883907436_82bf4a36b8.jpg
# /kaggle/input/flickr8k/Images/3192266178_f9bf5d3dba.jpg
# /kaggle/input/flickr8k/Images/2812125355_5e11a76533.jpg
# /kaggle/input/flickr8k/Images/292780636_72e1968949.jpg
# /kaggle/input/flickr8k/Images/3479423813_517e93a43a.jpg
# /kaggle/input/flickr8k/Images/3612538549_2828b45867.jpg
# /kaggle/input/flickr8k/Images/2656039837_f46b29af92.jpg
# /kaggle/input/flickr8k/Images/3424605029_53078d3505.jpg
# /kaggle/input/flickr8k/Images/472535997_0dbf42b9f3.jpg
# /kaggle/input/flickr8k/Images/3651107058_d84d4c3c25.jpg
# /kaggle/input/flickr8k/Images/2114355355_9d7e2d8178.jpg
# /kaggle/input/flickr8k/Images/3005872315_e6771763bd.jpg
# /kaggle/input/flickr8k/Images/3168796547_0c14b368f9.jpg
# /kaggle/input/flickr8k/Images/10815824_2997e03d76.jpg
# /kaggle/input/flickr8k/Images/3526018344_450c517a72.jpg
# /kaggle/input/flickr8k/Images/2813033949_e19fa08805.jpg
# /kaggle/input/flickr8k/Images/3222749441_3bdfe088e3.jpg
# /kaggle/input/flickr8k/Images/2514612680_b0d2d77099.jpg
# /kaggle/input/flickr8k/Images/3320680380_b0d38b3b4a.jpg
# /kaggle/input/flickr8k/Images/2975073156_7543ed326f.jpg
# /kaggle/input/flickr8k/Images/2351762979_0941aecced.jpg
# /kaggle/input/flickr8k/Images/2600386812_8790879d9a.jpg
# /kaggle/input/flickr8k/Images/241345905_5826a72da1.jpg
# /kaggle/input/flickr8k/Images/3532205154_5674b628ea.jpg
# /kaggle/input/flickr8k/Images/2096771662_984441d20d.jpg
# /kaggle/input/flickr8k/Images/1434607942_da5432c28c.jpg
# /kaggle/input/flickr8k/Images/3707077198_efd6aa808d.jpg
# /kaggle/input/flickr8k/Images/2789238858_14261dd25a.jpg
# /kaggle/input/flickr8k/Images/3543294190_0037c59607.jpg
# /kaggle/input/flickr8k/Images/997338199_7343367d7f.jpg
# /kaggle/input/flickr8k/Images/3665549027_d7fb05d157.jpg
# /kaggle/input/flickr8k/Images/468141298_3154d717e1.jpg
# /kaggle/input/flickr8k/Images/379006645_b9a2886b51.jpg
# /kaggle/input/flickr8k/Images/2458033289_f0616879df.jpg
# /kaggle/input/flickr8k/Images/2466495935_623b144183.jpg
# /kaggle/input/flickr8k/Images/3333675897_0043f992d3.jpg
# /kaggle/input/flickr8k/Images/2275372714_017c269742.jpg
# /kaggle/input/flickr8k/Images/2293149170_38fb2257ea.jpg
# /kaggle/input/flickr8k/Images/2945036454_280fa5b29f.jpg
# /kaggle/input/flickr8k/Images/888425986_e4b6c12324.jpg
# /kaggle/input/flickr8k/Images/3461106572_920c8c0112.jpg
# /kaggle/input/flickr8k/Images/3544233095_4bca71df1d.jpg
# /kaggle/input/flickr8k/Images/2599131872_65789d86d5.jpg
# /kaggle/input/flickr8k/Images/2480820830_bdec1f5b76.jpg
# /kaggle/input/flickr8k/Images/3451344589_6787bd06ef.jpg
# /kaggle/input/flickr8k/Images/3164328039_2c56acf594.jpg
# /kaggle/input/flickr8k/Images/2061354254_faa5bd294b.jpg
# /kaggle/input/flickr8k/Images/410042380_517ccee020.jpg
# /kaggle/input/flickr8k/Images/3595080592_5fd55570e5.jpg
# /kaggle/input/flickr8k/Images/1012212859_01547e3f17.jpg
# /kaggle/input/flickr8k/Images/3604383863_5e387cb8e6.jpg
# /kaggle/input/flickr8k/Images/3611672054_45edd3e08f.jpg
# /kaggle/input/flickr8k/Images/319870744_0e0138d205.jpg
# /kaggle/input/flickr8k/Images/505955292_026f1489f2.jpg
# /kaggle/input/flickr8k/Images/2862469183_a4334b904a.jpg
# /kaggle/input/flickr8k/Images/2908859957_e96c33c1e0.jpg
# /kaggle/input/flickr8k/Images/2741051940_89fb6b2cee.jpg
# /kaggle/input/flickr8k/Images/3626964430_cb5c7e5acc.jpg
# /kaggle/input/flickr8k/Images/2876993733_cb26107d18.jpg
# /kaggle/input/flickr8k/Images/3445428367_25bafffe75.jpg
# /kaggle/input/flickr8k/Images/3521201948_9049197f20.jpg
# /kaggle/input/flickr8k/Images/3025315215_a5d367971a.jpg
# /kaggle/input/flickr8k/Images/2414352262_005ae90407.jpg
# /kaggle/input/flickr8k/Images/3520199925_ca18d0f41e.jpg
# /kaggle/input/flickr8k/Images/300577375_26cc2773a1.jpg
# /kaggle/input/flickr8k/Images/3203908917_53e53c03d1.jpg
# /kaggle/input/flickr8k/Images/3385956569_a849218e34.jpg
# /kaggle/input/flickr8k/Images/3542771548_fcb8fa0cba.jpg
# /kaggle/input/flickr8k/Images/1403414927_5f80281505.jpg
# /kaggle/input/flickr8k/Images/3604384383_db6805d1b9.jpg
# /kaggle/input/flickr8k/Images/3532593368_be10432e92.jpg
# /kaggle/input/flickr8k/Images/411175971_0fffd3b8c6.jpg
# /kaggle/input/flickr8k/Images/485921585_1974b1577a.jpg
# /kaggle/input/flickr8k/Images/473988700_570422001b.jpg
# /kaggle/input/flickr8k/Images/2116444946_1f5d1fe5d1.jpg
# /kaggle/input/flickr8k/Images/3215315009_47577bf8f7.jpg
# /kaggle/input/flickr8k/Images/3566225740_375fc15dde.jpg
# /kaggle/input/flickr8k/Images/3002920707_5d2e6e6aac.jpg
# /kaggle/input/flickr8k/Images/3477715432_79d82487bb.jpg
# /kaggle/input/flickr8k/Images/2267819545_446c5a3e18.jpg
# /kaggle/input/flickr8k/Images/3015891201_2c1a9e5cd7.jpg
# /kaggle/input/flickr8k/Images/2939475047_84585ea45c.jpg
# /kaggle/input/flickr8k/Images/485738889_c2a00876a6.jpg
# /kaggle/input/flickr8k/Images/1479513774_70c94cf9d3.jpg
# /kaggle/input/flickr8k/Images/512101751_05a6d93e19.jpg
# /kaggle/input/flickr8k/Images/3501781809_88429e3b83.jpg
# /kaggle/input/flickr8k/Images/2414390475_28a0107bb0.jpg
# /kaggle/input/flickr8k/Images/95734036_bef6d1a871.jpg
# /kaggle/input/flickr8k/Images/3354075558_3b67eaa502.jpg
# /kaggle/input/flickr8k/Images/3217240672_b99a682026.jpg
# /kaggle/input/flickr8k/Images/241347356_8a515555fd.jpg
# /kaggle/input/flickr8k/Images/514222303_cb98584536.jpg
# /kaggle/input/flickr8k/Images/3486831913_2b9390ebbc.jpg
# /kaggle/input/flickr8k/Images/109823397_e35154645f.jpg
# /kaggle/input/flickr8k/Images/1294578091_2ad02fea91.jpg
# /kaggle/input/flickr8k/Images/514222285_aa0c8d05b7.jpg
# /kaggle/input/flickr8k/Images/2439031566_2e0c0d3550.jpg
# /kaggle/input/flickr8k/Images/3555231025_73fa54fa29.jpg
# /kaggle/input/flickr8k/Images/765091078_a8a11c6f9e.jpg
# /kaggle/input/flickr8k/Images/2255342813_5b2ac6d633.jpg
# /kaggle/input/flickr8k/Images/2272823323_3b7291cd47.jpg
# /kaggle/input/flickr8k/Images/2538423833_d1f492d1fb.jpg
# /kaggle/input/flickr8k/Images/495054019_3dee8a02f5.jpg
# /kaggle/input/flickr8k/Images/2544246151_727427ee07.jpg
# /kaggle/input/flickr8k/Images/2701271123_6761bc5f26.jpg
# /kaggle/input/flickr8k/Images/444057017_f1e0fcaef7.jpg
# /kaggle/input/flickr8k/Images/3122606953_a979dd3d33.jpg
# /kaggle/input/flickr8k/Images/3630991662_990f397f7c.jpg
# /kaggle/input/flickr8k/Images/1897025969_0c41688fa6.jpg
# /kaggle/input/flickr8k/Images/2883324329_24361e2d49.jpg
# /kaggle/input/flickr8k/Images/883040210_3c4a10f030.jpg
# /kaggle/input/flickr8k/Images/384465575_31294122c0.jpg
# /kaggle/input/flickr8k/Images/1118557877_736f339752.jpg
# /kaggle/input/flickr8k/Images/510791586_3913ade6a7.jpg
# /kaggle/input/flickr8k/Images/3608663656_9192a21eeb.jpg
# /kaggle/input/flickr8k/Images/2847514745_9a35493023.jpg
# /kaggle/input/flickr8k/Images/457875937_982588d918.jpg
# /kaggle/input/flickr8k/Images/2909875716_25c8652614.jpg
# /kaggle/input/flickr8k/Images/3760400645_3ba51d27f9.jpg
# /kaggle/input/flickr8k/Images/2745441424_5659f6acc8.jpg
# /kaggle/input/flickr8k/Images/2701895972_8605c4e038.jpg
# /kaggle/input/flickr8k/Images/2939007933_8a6ef2d073.jpg
# /kaggle/input/flickr8k/Images/3251906388_c09d44340e.jpg
# /kaggle/input/flickr8k/Images/2904997007_23d4b94101.jpg
# /kaggle/input/flickr8k/Images/299181827_8dc714101b.jpg
# /kaggle/input/flickr8k/Images/3672106148_56cfb5fc8d.jpg
# /kaggle/input/flickr8k/Images/3647826834_dc63e21bd0.jpg
# /kaggle/input/flickr8k/Images/3044359043_627488ddf0.jpg
# /kaggle/input/flickr8k/Images/3383491811_fd9d3a891d.jpg
# /kaggle/input/flickr8k/Images/136639119_6040b00946.jpg
# /kaggle/input/flickr8k/Images/3156113206_53c2a7b5d8.jpg
# /kaggle/input/flickr8k/Images/2479652566_8f9fac8af5.jpg
# /kaggle/input/flickr8k/Images/3293751640_d81a6f3a0c.jpg
# /kaggle/input/flickr8k/Images/2428275562_4bde2bc5ea.jpg
# /kaggle/input/flickr8k/Images/1489286545_8df476fa26.jpg
# /kaggle/input/flickr8k/Images/3106791484_13e18c33d8.jpg
# /kaggle/input/flickr8k/Images/2532294586_4cd76a837d.jpg
# /kaggle/input/flickr8k/Images/404702274_fa8b3fe378.jpg
# /kaggle/input/flickr8k/Images/2978394277_4572967b97.jpg
# /kaggle/input/flickr8k/Images/3435653630_3b6cca2c40.jpg
# /kaggle/input/flickr8k/Images/987907964_5a06a63609.jpg
# /kaggle/input/flickr8k/Images/2056377805_e9a9b3bcf0.jpg
# /kaggle/input/flickr8k/Images/2908512223_7e27631ed4.jpg
# /kaggle/input/flickr8k/Images/2478929971_9eb6c074b6.jpg
# /kaggle/input/flickr8k/Images/3643087589_627a0a9e01.jpg
# /kaggle/input/flickr8k/Images/2110898123_07729c1461.jpg
# /kaggle/input/flickr8k/Images/2560278143_aa5110aa37.jpg
# /kaggle/input/flickr8k/Images/3019473225_8e59b8ec4e.jpg
# /kaggle/input/flickr8k/Images/649596742_5ba84ce946.jpg
# /kaggle/input/flickr8k/Images/2084217208_7bd9bc85e5.jpg
# /kaggle/input/flickr8k/Images/3325497914_f9014d615b.jpg
# /kaggle/input/flickr8k/Images/3165826902_6bf9c4bdb2.jpg
# /kaggle/input/flickr8k/Images/2602306033_2b3100d36b.jpg
# /kaggle/input/flickr8k/Images/3075068274_2a28a5263b.jpg
# /kaggle/input/flickr8k/Images/3490517179_76dbd690de.jpg
# /kaggle/input/flickr8k/Images/2797185895_4d9e1e9508.jpg
# /kaggle/input/flickr8k/Images/2313822078_282dc07531.jpg
# /kaggle/input/flickr8k/Images/2414384480_096867d695.jpg
# /kaggle/input/flickr8k/Images/2790909995_8b7a03d9d1.jpg
# /kaggle/input/flickr8k/Images/3478877323_0a507a601b.jpg
# /kaggle/input/flickr8k/Images/2676184321_858eff416b.jpg
# /kaggle/input/flickr8k/Images/1232148178_4f45cc3284.jpg
# /kaggle/input/flickr8k/Images/667626_18933d713e.jpg
# /kaggle/input/flickr8k/Images/2930514856_784f17064a.jpg
# /kaggle/input/flickr8k/Images/2417745327_a2c2705043.jpg
# /kaggle/input/flickr8k/Images/3695064885_a6922f06b2.jpg
# /kaggle/input/flickr8k/Images/3595992258_6f192e6ae7.jpg
# /kaggle/input/flickr8k/Images/2084157130_f288e492e4.jpg
# /kaggle/input/flickr8k/Images/2195419145_36722e8d54.jpg
# /kaggle/input/flickr8k/Images/118309463_a532b75be9.jpg
# /kaggle/input/flickr8k/Images/3108197858_441ff38565.jpg
# /kaggle/input/flickr8k/Images/3524975665_7bec41578b.jpg
# /kaggle/input/flickr8k/Images/544122267_e9e0100bc5.jpg
# /kaggle/input/flickr8k/Images/1626754053_81126b67b6.jpg
# /kaggle/input/flickr8k/Images/2869765795_21a398cb24.jpg
# /kaggle/input/flickr8k/Images/324355356_859988a710.jpg
# /kaggle/input/flickr8k/Images/467858872_f3431df682.jpg
# /kaggle/input/flickr8k/Images/3106562372_e349a27764.jpg
# /kaggle/input/flickr8k/Images/3425071001_e7c9809ef2.jpg
# /kaggle/input/flickr8k/Images/533483374_86c5d4c13e.jpg
# /kaggle/input/flickr8k/Images/3447007090_08d997833a.jpg
# /kaggle/input/flickr8k/Images/3697003897_d8ac13be9a.jpg
# /kaggle/input/flickr8k/Images/3656151153_b4ed5d94c4.jpg
# /kaggle/input/flickr8k/Images/2959500257_3621429a37.jpg
# /kaggle/input/flickr8k/Images/2490179961_e842fda5eb.jpg
# /kaggle/input/flickr8k/Images/528498076_43f0ef36b5.jpg
# /kaggle/input/flickr8k/Images/3485657956_7481582565.jpg
# /kaggle/input/flickr8k/Images/2836703077_fa9c736203.jpg
# /kaggle/input/flickr8k/Images/152029243_b3582c36fa.jpg
# /kaggle/input/flickr8k/Images/3454199170_ae26917dcd.jpg
# /kaggle/input/flickr8k/Images/2483792149_a9b4ffecec.jpg
# /kaggle/input/flickr8k/Images/2445442929_8c81d42460.jpg
# /kaggle/input/flickr8k/Images/496129405_b9feeda1ab.jpg
# /kaggle/input/flickr8k/Images/468911753_cc595f5da0.jpg
# /kaggle/input/flickr8k/Images/3368865171_597d51cdd5.jpg
# /kaggle/input/flickr8k/Images/2807177340_bc85291df5.jpg
# /kaggle/input/flickr8k/Images/3643684616_9d2be87a5a.jpg
# /kaggle/input/flickr8k/Images/1414779054_31946f9dfc.jpg
# /kaggle/input/flickr8k/Images/290650302_ade636da35.jpg
# /kaggle/input/flickr8k/Images/468608014_09fd20eb9b.jpg
# /kaggle/input/flickr8k/Images/2641770481_c98465ff35.jpg
# /kaggle/input/flickr8k/Images/432490118_54a9c0e500.jpg
# /kaggle/input/flickr8k/Images/3592992234_6d3fe58a70.jpg
# /kaggle/input/flickr8k/Images/109202801_c6381eef15.jpg
# /kaggle/input/flickr8k/Images/1682079482_9a72fa57fa.jpg
# /kaggle/input/flickr8k/Images/3079786914_fe598b0e54.jpg
# /kaggle/input/flickr8k/Images/3463922449_f6040a2931.jpg
# /kaggle/input/flickr8k/Images/2447284966_d6bbdb4b6e.jpg
# /kaggle/input/flickr8k/Images/309430053_cc58bcc36a.jpg
# /kaggle/input/flickr8k/Images/3712574653_e009f76d19.jpg
# /kaggle/input/flickr8k/Images/3391209042_d2de8a8978.jpg
# /kaggle/input/flickr8k/Images/3501386648_e11e3f3152.jpg
# /kaggle/input/flickr8k/Images/3239866450_3f8cfb0c83.jpg
# /kaggle/input/flickr8k/Images/2301379282_5fbcf230d1.jpg
# /kaggle/input/flickr8k/Images/3226796100_08c49cfa5c.jpg
# /kaggle/input/flickr8k/Images/662606040_8cc8cd9f1b.jpg
# /kaggle/input/flickr8k/Images/3684518763_f3490b647a.jpg
# /kaggle/input/flickr8k/Images/1316247213_1d2c726dd5.jpg
# /kaggle/input/flickr8k/Images/2842609837_b3a0b383f7.jpg
# /kaggle/input/flickr8k/Images/3487419819_e3f89444ce.jpg
# /kaggle/input/flickr8k/Images/3713324467_104d72f7db.jpg
# /kaggle/input/flickr8k/Images/3104182973_5bb1c31275.jpg
# /kaggle/input/flickr8k/Images/322050103_145f7233c6.jpg
# /kaggle/input/flickr8k/Images/1459250022_bf1eddad11.jpg
# /kaggle/input/flickr8k/Images/3270083123_fcc1208053.jpg
# /kaggle/input/flickr8k/Images/3591094476_b61acd63d6.jpg
# /kaggle/input/flickr8k/Images/2967630001_cdc5560c0b.jpg
# /kaggle/input/flickr8k/Images/2301525531_edde12d673.jpg
# /kaggle/input/flickr8k/Images/1449692616_60507875fb.jpg
# /kaggle/input/flickr8k/Images/496971341_22782195f0.jpg
# /kaggle/input/flickr8k/Images/1015118661_980735411b.jpg
# /kaggle/input/flickr8k/Images/3392293702_ccb0599857.jpg
# /kaggle/input/flickr8k/Images/2315867011_fc5fc9fa6d.jpg
# /kaggle/input/flickr8k/Images/2766926202_4201bf2bf9.jpg
# /kaggle/input/flickr8k/Images/3522000960_47415c3890.jpg
# /kaggle/input/flickr8k/Images/3244747165_17028936e0.jpg
# /kaggle/input/flickr8k/Images/2453891449_fedb277908.jpg
# /kaggle/input/flickr8k/Images/3371266735_43150bce52.jpg
# /kaggle/input/flickr8k/Images/2577972703_a22c5f2a87.jpg
# /kaggle/input/flickr8k/Images/3266399073_40820596d5.jpg
# /kaggle/input/flickr8k/Images/2467850190_07a74d89b7.jpg
# /kaggle/input/flickr8k/Images/1348957576_c4a78eb974.jpg
# /kaggle/input/flickr8k/Images/300922408_05a4f9938c.jpg
# /kaggle/input/flickr8k/Images/3070130228_67dcfee9ae.jpg
# /kaggle/input/flickr8k/Images/3657209354_cde9bbd2c5.jpg
# /kaggle/input/flickr8k/Images/2325816912_b3bb41cdbb.jpg
# /kaggle/input/flickr8k/Images/2949982320_c704b31626.jpg
# /kaggle/input/flickr8k/Images/3186556417_b2d6921a20.jpg
# /kaggle/input/flickr8k/Images/3375134059_7e9eb2ef01.jpg
# /kaggle/input/flickr8k/Images/2710698257_2e4ca8dd44.jpg
# /kaggle/input/flickr8k/Images/2030781555_b7ff7be28f.jpg
# /kaggle/input/flickr8k/Images/478750151_e0adb5030a.jpg
# /kaggle/input/flickr8k/Images/3122579598_14841c038a.jpg
# /kaggle/input/flickr8k/Images/223299142_521aedf9e7.jpg
# /kaggle/input/flickr8k/Images/3094317837_b31cbf969e.jpg
# /kaggle/input/flickr8k/Images/2497074804_b4f3e7fd90.jpg
# /kaggle/input/flickr8k/Images/543940240_a54a3c7989.jpg
# /kaggle/input/flickr8k/Images/3325910784_5ecb88310c.jpg
# /kaggle/input/flickr8k/Images/2780105274_52360c4cca.jpg
# /kaggle/input/flickr8k/Images/470903027_489cc507de.jpg
# /kaggle/input/flickr8k/Images/2090339522_d30d2436f9.jpg
# /kaggle/input/flickr8k/Images/3143765063_a7761b16d3.jpg
# /kaggle/input/flickr8k/Images/2971478694_79e46ea7e5.jpg
# /kaggle/input/flickr8k/Images/246041128_bedb09ed74.jpg
# /kaggle/input/flickr8k/Images/2848571082_26454cb981.jpg
# /kaggle/input/flickr8k/Images/765298136_7805fbb079.jpg
# /kaggle/input/flickr8k/Images/58368365_03ed3e5bdf.jpg
# /kaggle/input/flickr8k/Images/2054869561_ff723e9eab.jpg
# /kaggle/input/flickr8k/Images/2944193661_7b255af9cc.jpg
# /kaggle/input/flickr8k/Images/428408242_b32faf2240.jpg
# /kaggle/input/flickr8k/Images/2276120079_4f235470bc.jpg
# /kaggle/input/flickr8k/Images/2697909987_128f11d1b7.jpg
# /kaggle/input/flickr8k/Images/2724485630_7d2452df00.jpg
# /kaggle/input/flickr8k/Images/3041384194_04316bd416.jpg
# /kaggle/input/flickr8k/Images/2531942624_c3c072064e.jpg
# /kaggle/input/flickr8k/Images/3033741581_136889ac73.jpg
# /kaggle/input/flickr8k/Images/3286193613_fc046e8016.jpg
# /kaggle/input/flickr8k/Images/53043785_c468d6f931.jpg
# /kaggle/input/flickr8k/Images/1287931016_fb015e2e10.jpg
# /kaggle/input/flickr8k/Images/345785626_9fa59f38ce.jpg
# /kaggle/input/flickr8k/Images/1361420539_e9599c60ae.jpg
# /kaggle/input/flickr8k/Images/3465791729_5bf9bd8635.jpg
# /kaggle/input/flickr8k/Images/2127031632_77505e4218.jpg
# /kaggle/input/flickr8k/Images/3447876218_4ccf42d7a0.jpg
# /kaggle/input/flickr8k/Images/1307635496_94442dc21a.jpg
# /kaggle/input/flickr8k/Images/399212516_d68046b277.jpg
# /kaggle/input/flickr8k/Images/1691573772_1adef8e40e.jpg
# /kaggle/input/flickr8k/Images/3525403875_7f95e0cbfe.jpg
# /kaggle/input/flickr8k/Images/2518094853_dfce24ce8c.jpg
# /kaggle/input/flickr8k/Images/2832978253_8fcc72da3b.jpg
# /kaggle/input/flickr8k/Images/1424237335_b3be9920ba.jpg
# /kaggle/input/flickr8k/Images/2660008870_b672a4c76a.jpg
# /kaggle/input/flickr8k/Images/3649387275_75295baa28.jpg
# /kaggle/input/flickr8k/Images/3638783842_af08dbb518.jpg
# /kaggle/input/flickr8k/Images/1479124077_17dcc0d5d7.jpg
# /kaggle/input/flickr8k/Images/3039209547_81cc93fbec.jpg
# /kaggle/input/flickr8k/Images/3372215826_b3e6403b2e.jpg
# /kaggle/input/flickr8k/Images/3652584682_5b5c43e445.jpg
# /kaggle/input/flickr8k/Images/377872472_35805fc143.jpg
# /kaggle/input/flickr8k/Images/3259231890_16fe167b31.jpg
# /kaggle/input/flickr8k/Images/1579798212_d30844b4c5.jpg
# /kaggle/input/flickr8k/Images/2744321686_8811d8428c.jpg
# /kaggle/input/flickr8k/Images/1401961581_76921a75c5.jpg
# /kaggle/input/flickr8k/Images/3569979711_6507841268.jpg
# /kaggle/input/flickr8k/Images/488089932_c3a5fa4140.jpg
# /kaggle/input/flickr8k/Images/3648160673_0c783236a6.jpg
# /kaggle/input/flickr8k/Images/2436398074_8737f40869.jpg
# /kaggle/input/flickr8k/Images/524698457_77ba13840a.jpg
# /kaggle/input/flickr8k/Images/3376435746_1593d9b243.jpg
# /kaggle/input/flickr8k/Images/3019857541_3de3e24f54.jpg
# /kaggle/input/flickr8k/Images/2187904131_96ea83b9b5.jpg
# /kaggle/input/flickr8k/Images/3180806542_49b6de312d.jpg
# /kaggle/input/flickr8k/Images/291952021_f111b0fb3d.jpg
# /kaggle/input/flickr8k/Images/3344531479_03c69750e9.jpg
# /kaggle/input/flickr8k/Images/3049649128_d83d847168.jpg
# /kaggle/input/flickr8k/Images/2423894412_d952d5d103.jpg
# /kaggle/input/flickr8k/Images/3225226381_9fe306fb9e.jpg
# /kaggle/input/flickr8k/Images/3542425197_2ef81c6051.jpg
# /kaggle/input/flickr8k/Images/3349451628_4249a21c8f.jpg
# /kaggle/input/flickr8k/Images/3217909454_7baa0edbb2.jpg
# /kaggle/input/flickr8k/Images/2635905544_dbc65d0622.jpg
# /kaggle/input/flickr8k/Images/3117336911_a729f42869.jpg
# /kaggle/input/flickr8k/Images/3216926094_bc975e84b9.jpg
# /kaggle/input/flickr8k/Images/799199774_142b1c3bb2.jpg
# /kaggle/input/flickr8k/Images/391324644_d23fdf06cb.jpg
# /kaggle/input/flickr8k/Images/1396064003_3fd949c9dd.jpg
# /kaggle/input/flickr8k/Images/3324746155_71e14f60ce.jpg
# /kaggle/input/flickr8k/Images/2998185688_8d33e4ce38.jpg
# /kaggle/input/flickr8k/Images/2631300484_be8621d17b.jpg
# /kaggle/input/flickr8k/Images/3030824089_e5a840265e.jpg
# /kaggle/input/flickr8k/Images/2633722629_5eeb649c09.jpg
# /kaggle/input/flickr8k/Images/210625425_fb1ef5d23b.jpg
# /kaggle/input/flickr8k/Images/3433470650_a8b1c27173.jpg
# /kaggle/input/flickr8k/Images/1597319381_1e80d9e39c.jpg
# /kaggle/input/flickr8k/Images/751737218_b89839a311.jpg
# /kaggle/input/flickr8k/Images/1240297429_c36ae0c58f.jpg
# /kaggle/input/flickr8k/Images/2219805677_7b7cc188c7.jpg
# /kaggle/input/flickr8k/Images/3108544687_c7115823f5.jpg
# /kaggle/input/flickr8k/Images/3733074526_82aa8d5f8d.jpg
# /kaggle/input/flickr8k/Images/2187222896_c206d63396.jpg
# /kaggle/input/flickr8k/Images/2271955077_0020b4ee0d.jpg
# /kaggle/input/flickr8k/Images/2506892928_7e79bec613.jpg
# /kaggle/input/flickr8k/Images/3658733605_fbcf570843.jpg
# /kaggle/input/flickr8k/Images/3258395783_2de3a4ba27.jpg
# /kaggle/input/flickr8k/Images/3342855466_44038a8aa3.jpg
# /kaggle/input/flickr8k/Images/3524914023_4e96edb09f.jpg
# /kaggle/input/flickr8k/Images/219730733_6a55382dd2.jpg
# /kaggle/input/flickr8k/Images/2360194369_d2fd03b337.jpg
# /kaggle/input/flickr8k/Images/12830823_87d2654e31.jpg
# /kaggle/input/flickr8k/Images/3607405494_0df89110a6.jpg
# /kaggle/input/flickr8k/Images/2843695880_eeea6c67db.jpg
# /kaggle/input/flickr8k/Images/2514581496_8f4102377e.jpg
# /kaggle/input/flickr8k/Images/2713554148_64cd465e71.jpg
# /kaggle/input/flickr8k/Images/3047144646_2252ff8e04.jpg
# /kaggle/input/flickr8k/Images/3516299821_8f0375d221.jpg
# /kaggle/input/flickr8k/Images/2484190118_e89363c465.jpg
# /kaggle/input/flickr8k/Images/3107368071_724613fc4f.jpg
# /kaggle/input/flickr8k/Images/1370615506_2b96105ca3.jpg
# /kaggle/input/flickr8k/Images/3644142276_caed26029e.jpg
# /kaggle/input/flickr8k/Images/3258472448_75cfab5e6f.jpg
# /kaggle/input/flickr8k/Images/2862509442_4f5dc96dca.jpg
# /kaggle/input/flickr8k/Images/3469585782_e708496552.jpg
# /kaggle/input/flickr8k/Images/3364151356_eecd07a23e.jpg
# /kaggle/input/flickr8k/Images/2402462857_7684848704.jpg
# /kaggle/input/flickr8k/Images/1007129816_e794419615.jpg
# /kaggle/input/flickr8k/Images/1417295167_5299df6db8.jpg
# /kaggle/input/flickr8k/Images/3555729342_cc7a3b67fd.jpg
# /kaggle/input/flickr8k/Images/2688102742_885e578a3f.jpg
# /kaggle/input/flickr8k/Images/953941506_5082c9160c.jpg
# /kaggle/input/flickr8k/Images/3435648640_b2f68efb78.jpg
# /kaggle/input/flickr8k/Images/538825260_a4a8784b75.jpg
# /kaggle/input/flickr8k/Images/2624044128_641b38c0cf.jpg
# /kaggle/input/flickr8k/Images/2343879696_59a82f496f.jpg
# /kaggle/input/flickr8k/Images/3315033940_e91f87b7f2.jpg
# /kaggle/input/flickr8k/Images/2642688531_8fb68b2147.jpg
# /kaggle/input/flickr8k/Images/3113769557_9edbb8275c.jpg
# /kaggle/input/flickr8k/Images/708860480_1a956ae0f7.jpg
# /kaggle/input/flickr8k/Images/1348304997_afe60a61df.jpg
# /kaggle/input/flickr8k/Images/700884207_d3ec546494.jpg
# /kaggle/input/flickr8k/Images/3470951932_27ed74eb0b.jpg
# /kaggle/input/flickr8k/Images/2629334536_11f2d49e05.jpg
# /kaggle/input/flickr8k/Images/2284239186_c827f4defa.jpg
# /kaggle/input/flickr8k/Images/483841513_e660391880.jpg
# /kaggle/input/flickr8k/Images/2255266906_8222af18b9.jpg
# /kaggle/input/flickr8k/Images/1363924449_487f0733df.jpg
# /kaggle/input/flickr8k/Images/3618115051_41b5a7706c.jpg
# /kaggle/input/flickr8k/Images/1402859872_0fc8cf8108.jpg
# /kaggle/input/flickr8k/Images/3035785330_2fd5e32bb1.jpg
# /kaggle/input/flickr8k/Images/1794818900_e0ffdd268e.jpg
# /kaggle/input/flickr8k/Images/437917001_ae1106f34e.jpg
# /kaggle/input/flickr8k/Images/2603125422_659391f961.jpg
# /kaggle/input/flickr8k/Images/543603259_ef26d9c72d.jpg
# /kaggle/input/flickr8k/Images/3482237861_605b4f0fd9.jpg
# /kaggle/input/flickr8k/Images/3726025663_e7d35d23f6.jpg
# /kaggle/input/flickr8k/Images/3640109324_3ce89e4d1a.jpg
# /kaggle/input/flickr8k/Images/2351479551_e8820a1ff3.jpg
# /kaggle/input/flickr8k/Images/374103776_0de490c1b0.jpg
# /kaggle/input/flickr8k/Images/3560771491_2a18b6241e.jpg
# /kaggle/input/flickr8k/Images/673806038_0a3682a83f.jpg
# /kaggle/input/flickr8k/Images/3182558164_488b819f14.jpg
# /kaggle/input/flickr8k/Images/462288558_b31a8a976f.jpg
# /kaggle/input/flickr8k/Images/3582914905_f58db879ae.jpg
# /kaggle/input/flickr8k/Images/3303648823_53cf750acd.jpg
# /kaggle/input/flickr8k/Images/2428797297_7fc3c862db.jpg
# /kaggle/input/flickr8k/Images/2602279427_191773c9e2.jpg
# /kaggle/input/flickr8k/Images/260828892_7925d27865.jpg
# /kaggle/input/flickr8k/Images/2838085973_42b6e9b5b1.jpg
# /kaggle/input/flickr8k/Images/3259992722_4c5e895734.jpg
# ...
# /kaggle/input/flickr8k/Images/3411595210_8e0893b266.jpg
# /kaggle/input/flickr8k/Images/3711611500_ea47b58b6f.jpg
# /kaggle/input/flickr8k/Images/2120411340_104eb610b1.jpg
# /kaggle/input/flickr8k/Images/3429641260_2f035c1813.jpg
# /kaggle/input/flickr8k/Images/3318564834_4ccea90497.jpg
# /kaggle/input/flickr8k/Images/2554081584_233bdf289a.jpg
# /kaggle/input/flickr8k/Images/493621130_152bdd4e91.jpg
# /kaggle/input/flickr8k/Images/716597900_b72c58362c.jpg
# /kaggle/input/flickr8k/Images/2276314067_7ee246f859.jpg
# /kaggle/input/flickr8k/Images/3640407952_bb38fb9d55.jpg
# /kaggle/input/flickr8k/Images/3401647850_685c03ffff.jpg
# /kaggle/input/flickr8k/Images/58363928_6f7074608c.jpg
# /kaggle/input/flickr8k/Images/3413806271_17b7e102aa.jpg
# /kaggle/input/flickr8k/Images/1386964743_9e80d96b05.jpg
# /kaggle/input/flickr8k/Images/3077166963_fe172c709d.jpg
# /kaggle/input/flickr8k/Images/96420612_feb18fc6c6.jpg
# /kaggle/input/flickr8k/Images/2444134813_20895c640c.jpg
# /kaggle/input/flickr8k/Images/3348785391_c243faf6bb.jpg
# /kaggle/input/flickr8k/Images/3289433994_4c67aab384.jpg
# /kaggle/input/flickr8k/Images/2151300603_248a9fe715.jpg
# /kaggle/input/flickr8k/Images/3473534758_1ae3847781.jpg
# /kaggle/input/flickr8k/Images/1482960952_95f2d419cb.jpg
# /kaggle/input/flickr8k/Images/3158327361_6f1a518228.jpg
# /kaggle/input/flickr8k/Images/490390951_87395fcb1c.jpg
# /kaggle/input/flickr8k/Images/3210359094_ee51285301.jpg
# /kaggle/input/flickr8k/Images/2511762757_bd0ab0a017.jpg
# /kaggle/input/flickr8k/Images/2836360729_6500249fe6.jpg
# /kaggle/input/flickr8k/Images/3150252702_828a570d46.jpg
# /kaggle/input/flickr8k/Images/1473080948_bae2925dc8.jpg
# /kaggle/input/flickr8k/Images/3290465391_258429e2f9.jpg
# /kaggle/input/flickr8k/Images/3582048078_7bac2d8473.jpg
# /kaggle/input/flickr8k/Images/2534502836_7a75305655.jpg
# /kaggle/input/flickr8k/Images/3272071680_648a99f7d2.jpg
# /kaggle/input/flickr8k/Images/238512430_30dc12b683.jpg
# /kaggle/input/flickr8k/Images/2302747917_aa0300eb68.jpg
# /kaggle/input/flickr8k/Images/3425851292_de92a072ee.jpg
# /kaggle/input/flickr8k/Images/2875658507_c0d9ceae90.jpg
# /kaggle/input/flickr8k/Images/3613027188_1645ca1976.jpg
# /kaggle/input/flickr8k/Images/3132903412_b4780d0ccf.jpg
# /kaggle/input/flickr8k/Images/424379231_23f1ade134.jpg
# /kaggle/input/flickr8k/Images/3738789925_7d17dbdf25.jpg
# /kaggle/input/flickr8k/Images/393810324_1c33760a95.jpg
# /kaggle/input/flickr8k/Images/2141713971_e25eb12712.jpg
# /kaggle/input/flickr8k/Images/2524084967_a5e011b73d.jpg
# /kaggle/input/flickr8k/Images/3266261886_36e1323d2f.jpg
# /kaggle/input/flickr8k/Images/2446601467_a35841cb1d.jpg
# /kaggle/input/flickr8k/Images/2480664591_e6d22ed61c.jpg
# /kaggle/input/flickr8k/Images/3508882611_3947c0dbf5.jpg
# /kaggle/input/flickr8k/Images/3384742888_85230c34d5.jpg
# /kaggle/input/flickr8k/Images/450596617_ed37ec0fe4.jpg
# /kaggle/input/flickr8k/Images/288880576_818b6ecfef.jpg
# /kaggle/input/flickr8k/Images/3346614841_698f9aa486.jpg
# /kaggle/input/flickr8k/Images/3255017708_2b02bfcdcf.jpg
# /kaggle/input/flickr8k/Images/140526327_3cb984de09.jpg
# /kaggle/input/flickr8k/Images/390992102_67fa31b22f.jpg
# /kaggle/input/flickr8k/Images/435054077_3506dbfcf4.jpg
# /kaggle/input/flickr8k/Images/3610683688_bbe6d725ed.jpg
# /kaggle/input/flickr8k/Images/2561212119_1af8cb9b5d.jpg
# /kaggle/input/flickr8k/Images/3319489465_c65c91e4f2.jpg
# /kaggle/input/flickr8k/Images/3409740108_1505489537.jpg
# /kaggle/input/flickr8k/Images/801607443_f15956d1ce.jpg
# /kaggle/input/flickr8k/Images/2934325103_e9b8d7430f.jpg
# /kaggle/input/flickr8k/Images/3223709894_97824ba76f.jpg
# /kaggle/input/flickr8k/Images/2833431496_09d999db4d.jpg
# /kaggle/input/flickr8k/Images/3287969199_08e775d896.jpg
# /kaggle/input/flickr8k/Images/161905204_247c6ca6de.jpg
# /kaggle/input/flickr8k/Images/3381584882_341ee3092f.jpg
# /kaggle/input/flickr8k/Images/3568225554_73cdb19576.jpg
# /kaggle/input/flickr8k/Images/3334953664_a669038795.jpg
# /kaggle/input/flickr8k/Images/3342309960_c694b2cce9.jpg
# /kaggle/input/flickr8k/Images/128912885_8350d277a4.jpg
# /kaggle/input/flickr8k/Images/295433203_8185c13e08.jpg
# /kaggle/input/flickr8k/Images/2855667597_bf6ceaef8e.jpg
# /kaggle/input/flickr8k/Images/451081733_40218cec31.jpg
# /kaggle/input/flickr8k/Images/872622575_ba1d3632cc.jpg
# /kaggle/input/flickr8k/Images/524031846_28b11bc0e5.jpg
# /kaggle/input/flickr8k/Images/3658427967_6e2e57458d.jpg
# /kaggle/input/flickr8k/Images/497122685_a51b29dc46.jpg
# /kaggle/input/flickr8k/Images/370713359_7560808550.jpg
# /kaggle/input/flickr8k/Images/265223847_636ba039c1.jpg
# /kaggle/input/flickr8k/Images/3537452619_3bd79f24e0.jpg
# /kaggle/input/flickr8k/Images/2451114871_8617ae2f16.jpg
# /kaggle/input/flickr8k/Images/2080033499_6be742f483.jpg
# /kaggle/input/flickr8k/Images/3159641529_c2c74f3eaf.jpg
# /kaggle/input/flickr8k/Images/3530502404_f8c3a3f61c.jpg
# /kaggle/input/flickr8k/Images/2892395757_0a1b0eedd2.jpg
# /kaggle/input/flickr8k/Images/3519942322_b37d088aae.jpg
# /kaggle/input/flickr8k/Images/2293424366_7b5fcd2398.jpg
# /kaggle/input/flickr8k/Images/3726700898_c50494b8bd.jpg
# /kaggle/input/flickr8k/Images/1499495021_d295ce577c.jpg
# /kaggle/input/flickr8k/Images/274313927_404d0e94ab.jpg
# /kaggle/input/flickr8k/Images/1383840121_c092110917.jpg
# /kaggle/input/flickr8k/Images/3621652774_fd9634bd5b.jpg
# /kaggle/input/flickr8k/Images/3102204862_f1d220230b.jpg
# /kaggle/input/flickr8k/Images/2495931537_9b8d4474b6.jpg
# /kaggle/input/flickr8k/Images/2795352290_9209b214f3.jpg
# /kaggle/input/flickr8k/Images/142802798_962a4ec5ce.jpg
# /kaggle/input/flickr8k/Images/3475581086_a533567561.jpg
# /kaggle/input/flickr8k/Images/543007912_23fc735b99.jpg
# /kaggle/input/flickr8k/Images/19212715_20476497a3.jpg
# /kaggle/input/flickr8k/Images/3259160693_067ec7ebc3.jpg
# /kaggle/input/flickr8k/Images/3062173277_bfb5ef4c45.jpg
# /kaggle/input/flickr8k/Images/1252787177_4b08625897.jpg
# /kaggle/input/flickr8k/Images/3421480658_b3518b6819.jpg
# /kaggle/input/flickr8k/Images/637342973_89f6fac1f7.jpg
# /kaggle/input/flickr8k/Images/241346105_c1c860db0d.jpg
# /kaggle/input/flickr8k/Images/3431121650_056db85987.jpg
# /kaggle/input/flickr8k/Images/1937262236_cbf5bfa101.jpg
# /kaggle/input/flickr8k/Images/503794526_603a7954d3.jpg
# /kaggle/input/flickr8k/Images/2038662925_f4fa8c2534.jpg
# /kaggle/input/flickr8k/Images/2695085862_2ed62df354.jpg
# /kaggle/input/flickr8k/Images/2396100671_3a9d67f03d.jpg
# /kaggle/input/flickr8k/Images/146098876_0d99d7fb98.jpg
# /kaggle/input/flickr8k/Images/3211556865_d1d9becf69.jpg
# /kaggle/input/flickr8k/Images/2333584535_1eaf9baf3e.jpg
# /kaggle/input/flickr8k/Images/2878578240_caf64c3b19.jpg
# /kaggle/input/flickr8k/Images/3604314527_5077cd9d43.jpg
# /kaggle/input/flickr8k/Images/766346887_a9a9d0637a.jpg
# /kaggle/input/flickr8k/Images/3197891333_b1b0fd1702.jpg
# /kaggle/input/flickr8k/Images/1969573381_5ecfae4c80.jpg
# /kaggle/input/flickr8k/Images/3169777863_d745865784.jpg
# /kaggle/input/flickr8k/Images/2856456013_335297f587.jpg
# /kaggle/input/flickr8k/Images/2287023569_fd7a9c60b8.jpg
# /kaggle/input/flickr8k/Images/3174156702_95a1cda2d9.jpg
# /kaggle/input/flickr8k/Images/2363419943_717e6b119d.jpg
# /kaggle/input/flickr8k/Images/1244485675_822e6efe60.jpg
# /kaggle/input/flickr8k/Images/2909609550_070eea49b5.jpg
# /kaggle/input/flickr8k/Images/1389323170_d1c81d6b51.jpg
# /kaggle/input/flickr8k/Images/3021318991_fa28e3bca7.jpg
# /kaggle/input/flickr8k/Images/310213587_778fe8fb5b.jpg
# /kaggle/input/flickr8k/Images/2466171100_5e60cfcc11.jpg
# /kaggle/input/flickr8k/Images/693450725_8ad72389e6.jpg
# /kaggle/input/flickr8k/Images/3195969533_98f5de0fab.jpg
# /kaggle/input/flickr8k/Images/3359089834_263e529c71.jpg
# /kaggle/input/flickr8k/Images/3606942887_1159d92548.jpg
# /kaggle/input/flickr8k/Images/3401437960_7da856e004.jpg
# /kaggle/input/flickr8k/Images/299676757_571ee47280.jpg
# /kaggle/input/flickr8k/Images/2120571547_05cd56de85.jpg
# /kaggle/input/flickr8k/Images/3138562460_44227a35cf.jpg
# /kaggle/input/flickr8k/Images/145721498_a27d2db576.jpg
# /kaggle/input/flickr8k/Images/3228960484_9aab98b91a.jpg
# /kaggle/input/flickr8k/Images/3217910740_d1d61c08ab.jpg
# /kaggle/input/flickr8k/Images/3277824093_299cbb3138.jpg
# /kaggle/input/flickr8k/Images/2584020755_14e2b3e8fc.jpg
# /kaggle/input/flickr8k/Images/2570559405_dc93007f76.jpg
# /kaggle/input/flickr8k/Images/3688839836_ba5e4c24fc.jpg
# /kaggle/input/flickr8k/Images/295258727_eaf75e0887.jpg
# /kaggle/input/flickr8k/Images/3397220683_4aca010f86.jpg
# /kaggle/input/flickr8k/Images/3419197575_aa5b84a9f0.jpg
# /kaggle/input/flickr8k/Images/3329793486_afc16663cc.jpg
# /kaggle/input/flickr8k/Images/429205889_ff5a006311.jpg
# /kaggle/input/flickr8k/Images/299178969_5ca1de8e40.jpg
# /kaggle/input/flickr8k/Images/3029928396_99ac250788.jpg
# /kaggle/input/flickr8k/Images/1427391496_ea512cbe7f.jpg
# /kaggle/input/flickr8k/Images/2938747424_64e64784f0.jpg
# /kaggle/input/flickr8k/Images/1389264266_8170bc1c54.jpg
# /kaggle/input/flickr8k/Images/549887636_0ea5ae4739.jpg
# /kaggle/input/flickr8k/Images/2061144717_5b3a1864f0.jpg
# /kaggle/input/flickr8k/Images/642987597_03b21a1437.jpg
# /kaggle/input/flickr8k/Images/298920219_9a3f80acc5.jpg
# /kaggle/input/flickr8k/Images/260520547_944f9f4c91.jpg
# /kaggle/input/flickr8k/Images/3208074567_ac44aeb3f3.jpg
# /kaggle/input/flickr8k/Images/539493431_744eb1abaa.jpg
# /kaggle/input/flickr8k/Images/875731481_a5a0a09934.jpg
# /kaggle/input/flickr8k/Images/3710353645_8fbfaa4175.jpg
# /kaggle/input/flickr8k/Images/3455920874_6fbec43194.jpg
# /kaggle/input/flickr8k/Images/2303426046_09cfd7bc4e.jpg
# /kaggle/input/flickr8k/Images/3673878924_506c9d767b.jpg
# /kaggle/input/flickr8k/Images/2431120202_b24fe2333a.jpg
# /kaggle/input/flickr8k/Images/3585117340_73e96b6173.jpg
# /kaggle/input/flickr8k/Images/2684489465_32ba1d0344.jpg
# /kaggle/input/flickr8k/Images/2125626631_a4b63af97e.jpg
# /kaggle/input/flickr8k/Images/2496236371_61dec88113.jpg
# /kaggle/input/flickr8k/Images/1289142574_2bd6a082dd.jpg
# /kaggle/input/flickr8k/Images/566446626_9793890f95.jpg
# /kaggle/input/flickr8k/Images/3457572788_e1fe4f6480.jpg
# /kaggle/input/flickr8k/Images/1358892595_7a37c45788.jpg
# /kaggle/input/flickr8k/Images/3106782647_b078830a9e.jpg
# /kaggle/input/flickr8k/Images/3101796900_59c15e0edc.jpg
# /kaggle/input/flickr8k/Images/3222250187_ef610f267e.jpg
# /kaggle/input/flickr8k/Images/743571049_68080e8751.jpg
# /kaggle/input/flickr8k/Images/3415003392_139c0f3586.jpg
# /kaggle/input/flickr8k/Images/254295381_d98fa049f4.jpg
# /kaggle/input/flickr8k/Images/3331190056_09f4ca9fd2.jpg
# /kaggle/input/flickr8k/Images/1490213660_9ea45550cf.jpg
# /kaggle/input/flickr8k/Images/3181328245_7c04ce1691.jpg
# /kaggle/input/flickr8k/Images/1417031097_ab656bc4bd.jpg
# /kaggle/input/flickr8k/Images/3276895962_c053263d01.jpg
# /kaggle/input/flickr8k/Images/3692836015_d11180727b.jpg
# /kaggle/input/flickr8k/Images/3286406057_a1668655af.jpg
# /kaggle/input/flickr8k/Images/350176185_b8c5591e36.jpg
# /kaggle/input/flickr8k/Images/3491607076_922ec561d9.jpg
# /kaggle/input/flickr8k/Images/2279980395_989d48ae72.jpg
# /kaggle/input/flickr8k/Images/3437781040_82b06facb3.jpg
# /kaggle/input/flickr8k/Images/1387443857_602ab6f9bf.jpg
# /kaggle/input/flickr8k/Images/1248357227_2b4175fc39.jpg
# /kaggle/input/flickr8k/Images/3453284877_8866189055.jpg
# /kaggle/input/flickr8k/Images/3244470342_c08f6bb17e.jpg
# /kaggle/input/flickr8k/Images/330849796_c575c3108a.jpg
# /kaggle/input/flickr8k/Images/2687229880_97cfd8148e.jpg
# /kaggle/input/flickr8k/Images/2274602044_b3d55df235.jpg
# /kaggle/input/flickr8k/Images/3016726158_4d15b83b06.jpg
# /kaggle/input/flickr8k/Images/2448270671_5e0e391a80.jpg
# /kaggle/input/flickr8k/Images/2188688248_f57a28a5a7.jpg
# /kaggle/input/flickr8k/Images/3430100177_5864bf1e73.jpg
# /kaggle/input/flickr8k/Images/3374223949_90776ba934.jpg
# /kaggle/input/flickr8k/Images/2261962622_e9318a95eb.jpg
# /kaggle/input/flickr8k/Images/3208553539_2bf6c6d162.jpg
# /kaggle/input/flickr8k/Images/2647394564_4843800cff.jpg
# /kaggle/input/flickr8k/Images/698107542_3aa0ba78b4.jpg
# /kaggle/input/flickr8k/Images/437404867_209625774d.jpg
# /kaggle/input/flickr8k/Images/2830309113_c79d7be554.jpg
# /kaggle/input/flickr8k/Images/3724113279_99b6e5bf41.jpg
# /kaggle/input/flickr8k/Images/3681324243_b69fa90842.jpg
# /kaggle/input/flickr8k/Images/236518934_c62a133077.jpg
# /kaggle/input/flickr8k/Images/3038045802_93f2cd5fbc.jpg
# /kaggle/input/flickr8k/Images/3234719720_5bb2fc5ffa.jpg
# /kaggle/input/flickr8k/Images/3042483842_beb23828b9.jpg
# /kaggle/input/flickr8k/Images/2699426519_228719b1db.jpg
# /kaggle/input/flickr8k/Images/240583223_e26e17ee96.jpg
# /kaggle/input/flickr8k/Images/2128119486_4407061c40.jpg
# /kaggle/input/flickr8k/Images/2444741900_5cb3ef3e1d.jpg
# /kaggle/input/flickr8k/Images/1807169176_7f5226bf5a.jpg
# /kaggle/input/flickr8k/Images/247691240_3881777ab8.jpg
# /kaggle/input/flickr8k/Images/525968880_82623392d1.jpg
# /kaggle/input/flickr8k/Images/1406010299_5755339f08.jpg
# /kaggle/input/flickr8k/Images/3530504007_3272c57e21.jpg
# /kaggle/input/flickr8k/Images/3694219419_a7a83d4886.jpg
# /kaggle/input/flickr8k/Images/2256138896_3e24b0b28d.jpg
# /kaggle/input/flickr8k/Images/159712188_d530dd478c.jpg
# /kaggle/input/flickr8k/Images/3724150944_fc62e8d5e0.jpg
# /kaggle/input/flickr8k/Images/1418266617_b32143275b.jpg
# /kaggle/input/flickr8k/Images/2698614194_b4e6e11dff.jpg
# /kaggle/input/flickr8k/Images/759015118_4bd3617e60.jpg
# /kaggle/input/flickr8k/Images/1763020597_d4cc8f0f8a.jpg
# /kaggle/input/flickr8k/Images/1581822598_0ae23074f1.jpg
# /kaggle/input/flickr8k/Images/406642021_9ec852eccf.jpg
# /kaggle/input/flickr8k/Images/899810584_61e1578d3f.jpg
# /kaggle/input/flickr8k/Images/2501742763_b2cb322087.jpg
# /kaggle/input/flickr8k/Images/2934837034_a8ca5b1f50.jpg
# /kaggle/input/flickr8k/Images/3677693858_62f2f3163f.jpg
# /kaggle/input/flickr8k/Images/2918880895_e61f74f2f0.jpg
# /kaggle/input/flickr8k/Images/3175849727_bf30b892cb.jpg
# /kaggle/input/flickr8k/Images/3704995657_e2e114083d.jpg
# /kaggle/input/flickr8k/Images/3339140382_2e49bc324a.jpg
# /kaggle/input/flickr8k/Images/2660480624_45f88b3022.jpg
# /kaggle/input/flickr8k/Images/652542470_60e858da64.jpg
# /kaggle/input/flickr8k/Images/3636543173_15f56515e5.jpg
# /kaggle/input/flickr8k/Images/3125158798_0743dae56e.jpg
# /kaggle/input/flickr8k/Images/3459492423_c881f12c9f.jpg
# /kaggle/input/flickr8k/Images/3500136982_bf7a85531e.jpg
# /kaggle/input/flickr8k/Images/412101267_7257e6d8c0.jpg
# /kaggle/input/flickr8k/Images/3354883962_170d19bfe4.jpg
# /kaggle/input/flickr8k/Images/3549277110_24d4064ccd.jpg
# /kaggle/input/flickr8k/Images/3255732353_fbc487aefc.jpg
# /kaggle/input/flickr8k/Images/3322443827_a04a94bb91.jpg
# /kaggle/input/flickr8k/Images/1579198375_84b18e003a.jpg
# /kaggle/input/flickr8k/Images/3330019493_fd36fbc2ea.jpg
# /kaggle/input/flickr8k/Images/3335370208_460fc19bfa.jpg
# /kaggle/input/flickr8k/Images/2774581025_81a3074e2e.jpg
# /kaggle/input/flickr8k/Images/3569420080_72fbe84751.jpg
# /kaggle/input/flickr8k/Images/533713007_bf9f3e25b4.jpg
# /kaggle/input/flickr8k/Images/2266142543_b2de18c081.jpg
# /kaggle/input/flickr8k/Images/3074617663_2f2634081d.jpg
# /kaggle/input/flickr8k/Images/3249014584_21dd9ddd9d.jpg
# /kaggle/input/flickr8k/Images/3294830188_e46bd9b93c.jpg
# /kaggle/input/flickr8k/Images/3272002857_ace031f564.jpg
# /kaggle/input/flickr8k/Images/3346040664_5b584e6133.jpg
# /kaggle/input/flickr8k/Images/3512033861_a357bb58b6.jpg
# /kaggle/input/flickr8k/Images/498444334_a680d318a1.jpg
# /kaggle/input/flickr8k/Images/2473791980_805c819bd4.jpg
# /kaggle/input/flickr8k/Images/2993167197_e5d0a73530.jpg
# /kaggle/input/flickr8k/Images/3364258732_9942c557e5.jpg
# /kaggle/input/flickr8k/Images/3081363964_d404eccae8.jpg
# /kaggle/input/flickr8k/Images/3684562647_28dc325522.jpg
# /kaggle/input/flickr8k/Images/1287073593_f3d2a62455.jpg
# /kaggle/input/flickr8k/Images/2543679402_9359e1ee4e.jpg
# /kaggle/input/flickr8k/Images/608257195_6ec6f48e37.jpg
# /kaggle/input/flickr8k/Images/3374384485_751f719be4.jpg
# /kaggle/input/flickr8k/Images/3189941492_a3f4347b1a.jpg
# /kaggle/input/flickr8k/Images/3674565156_14d3b41450.jpg
# /kaggle/input/flickr8k/Images/272283076_2d4aa1d5cf.jpg
# /kaggle/input/flickr8k/Images/281419391_522557ce27.jpg
# /kaggle/input/flickr8k/Images/590445887_4d4fa43923.jpg
# /kaggle/input/flickr8k/Images/502115726_927dd684d3.jpg
# /kaggle/input/flickr8k/Images/3025438110_40af7e6a80.jpg
# /kaggle/input/flickr8k/Images/2623982903_58ec7c5026.jpg

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, add
from tensorflow.keras.layers import Flatten, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from sklearn.model_selection import train_test_split
from PIL import Image
from tqdm import tqdm_notebook
from collections import Counter
import re

# %%
images_directory = '/kaggle/input/flickr8k/Images/'
captions_path = '/kaggle/input/flickr8k/captions.txt'
def load_captions(file_path):
    with open(file_path, 'r') as f:
        captions = f.readlines()
        captions = [caption.lower() for caption in captions[1:]]
    return captions

def tokenize_captions(captions):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(captions)
    return tokenizer

captions = load_captions(captions_path)
captions[:15:3]
# Out:
# ['1000268201_693b08cb0e.jpg,a child in a pink dress is climbing up a set of stairs in an entry way .\n',
#  '1000268201_693b08cb0e.jpg,a little girl climbing the stairs to her playhouse .\n',
#  '1001773457_577c3a7d70.jpg,a black dog and a tri-colored dog playing with each other on the road .\n',
#  '1001773457_577c3a7d70.jpg,two dogs on pavement moving toward each other .\n',
#  '1002674143_1b742ab4b8.jpg,a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it .\n']

# %%
def clean_text(text):
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

cleaned_captions = [clean_text(caption.split(',')[1]) for caption in captions]
cleaned_captions[:15:2]
# Out:
# ['a child in a pink dress is climbing up a set of stairs in an entry way',
#  'a little girl climbing into a wooden playhouse',
#  'a little girl in a pink dress going into a wooden cabin',
#  'a black dog and a tricolored dog playing with each other on the road',
#  'two dogs of different breeds looking at each other on the road',
#  'a little girl covered in paint sits in front of a painted rainbow with her hands in a bowl',
#  'a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it',
#  'young girl with pigtails painting outside in the grass']

# %%
captions_IDs = []
for i in range(len(cleaned_captions)):
    item = captions[i].split(',')[0]+'\t'+'start '+cleaned_captions[i]+' end\n'
    captions_IDs.append(item)

captions_IDs[:20:3], len(captions_IDs)
# Out:
# (['1000268201_693b08cb0e.jpg\tstart a child in a pink dress is climbing up a set of stairs in an entry way end\n',
#   '1000268201_693b08cb0e.jpg\tstart a little girl climbing the stairs to her playhouse end\n',
#   '1001773457_577c3a7d70.jpg\tstart a black dog and a tricolored dog playing with each other on the road end\n',
#   '1001773457_577c3a7d70.jpg\tstart two dogs on pavement moving toward each other end\n',
#   '1002674143_1b742ab4b8.jpg\tstart a small girl in the grass plays with fingerpaints in front of a white canvas with a rainbow on it end\n',
#   '1003163366_44323f5815.jpg\tstart a man lays on a bench while his dog sits by him end\n',
#   '1003163366_44323f5815.jpg\tstart a shirtless man lies on a park bench with his dog end\n'],
#  40455)

# %%
def visualaization(data, num_of_images):
    captions_dictionary = {}
    for item in data[100:100+(num_of_images)*5]:
        image_id, caption = item.split('\t')
        if image_id not in captions_dictionary:
            captions_dictionary[image_id] = []
        captions_dictionary[image_id].append(caption)
    else:
        list_captions = [x for x in captions_dictionary.items()]

    count = 1
    fig = plt.figure(figsize=(10,20))
    for filename in list(captions_dictionary.keys()):
        captions = captions_dictionary[filename]
        image_load = load_img(images_directory+filename, target_size=(199,199,3))

        ax = fig.add_subplot(num_of_images,2,count,xticks=[],yticks=[])
        ax.imshow(image_load)
        count += 1

        ax = fig.add_subplot(num_of_images,2,count)
        plt.axis('off')
        ax.plot()
        ax.set_xlim(0,1)
        ax.set_ylim(0,len(captions))
        for i, caption in enumerate(captions):
            ax.text(0,i,caption,fontsize=20)
        count += 1
    plt.show()

visualaization(captions_IDs, 5)

# %%
def captions_length(data):
    plt.figure(figsize=(15, 7), dpi=300)
    sns.set_style('darkgrid')
    sns.histplot(x=[len(x.split(' ')) for x in data], kde=True, binwidth=1)
    plt.title('Captions length histogram', fontsize=15, fontweight='bold')
    plt.xticks(fontweight='bold')
    plt.yticks(fontweight='bold')
    plt.xlabel('Length', fontweight='bold')
    plt.ylabel('Freaquency', fontweight='bold')
    plt.show()

captions_length(cleaned_captions)

# %%
tokenizer = tokenize_captions(cleaned_captions)
vocab_size = len(tokenizer.word_index) + 1
vocab_size
# Out:
# 8586

# %%
all_image_ids = os.listdir(images_directory)

train_image_ids, val_image_ids = train_test_split(all_image_ids, test_size=0.15, random_state=42)
val_image_ids, test_image_ids = train_test_split(val_image_ids, test_size=0.1, random_state=42)

train_captions, val_captions, test_captions = [], [], []
for caption in captions_IDs:
    image_id, _ = caption.split('\t')

    if image_id in train_image_ids:
        train_captions.append(caption)

    elif image_id in val_image_ids:
        val_captions.append(caption)

    elif image_id in test_image_ids:
        test_captions.append(caption)

    else:
        print('Unknown image ID !')

train_captions[0], val_captions[0], test_captions[0], len(train_captions)/5, len(val_captions)/5, len(test_captions)/5
# Out:
# ('1000268201_693b08cb0e.jpg\tstart a child in a pink dress is climbing up a set of stairs in an entry way end\n',
#  '1001773457_577c3a7d70.jpg\tstart a black dog and a spotted dog are fighting end\n',
#  '1042590306_95dea0916c.jpg\tstart a man and woman pose for the camera while another man looks on end\n',
#  6877.0,
#  1092.0,
#  122.0)

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(299, 299))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img

def extract_image_features(model, image_path):
    img = preprocess_image(image_path)
    features = model.predict(img, verbose=0)
    return features

inception_v3_model = InceptionV3(weights = 'imagenet', input_shape=(299, 299, 3))
inception_v3_model.layers.pop()
inception_v3_model = Model(inputs=inception_v3_model.inputs, outputs=inception_v3_model.layers[-2].output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96112376/96112376 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
train_image_features, val_image_features, test_image_features = {}, {}, {}  # A Dictionary to store image features with their corresponding IDs

pbar = tqdm_notebook(total=len(all_image_ids), position=0, leave=True, colour='green')

for caption in all_image_ids:
    image_id = caption.split('\t')[0]
    image_path = os.path.join(images_directory, image_id)
    image_features = extract_image_features(inception_v3_model, image_path) # Extracting features

    if image_id in train_image_ids:
        train_image_features[image_id] = image_features.flatten()  # Flattening the features
        pbar.update(1)

    elif image_id in val_image_ids:
        val_image_features[image_id] = image_features.flatten()  # Flattening the features
        pbar.update(1)

    elif image_id in test_image_ids:
        test_image_features[image_id] = image_features.flatten()  # Flattening the features
        pbar.update(1)

    else:
        print('Unknown image ID !')

pbar.close()
# Out:
#   0%|          | 0/8091 [00:00<?, ?it/s]

# %%
def data_generator(captions, image_features, tokenizer, max_caption_length, batch_size):
    num_samples = len(captions)
    image_ids = list(image_features.keys())
    while True:
        np.random.shuffle(image_ids)  # Shuffle image_ids for each epoch
        for start_idx in range(0, num_samples, batch_size):
            end_idx = min(start_idx + batch_size, num_samples)
            X_images, X_captions, y = [], [], []
            for caption in captions[start_idx:end_idx]:
                image_id, caption_text = caption.split('\t')
                caption_text = caption_text.rstrip('\n')
                seq = tokenizer.texts_to_sequences([caption_text])[0] # Tokenizing the caption
                for i in range(1, len(seq)):
                    in_seq, out_seq = seq[:i], seq[i] # X_caption, Y
                    in_seq = pad_sequences([in_seq], maxlen=max_caption_length)[0]
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    X_images.append(image_features[image_id])
                    X_captions.append(in_seq)
                    y.append(out_seq)

            yield (np.array(X_images), np.array(X_captions)), np.array(y)


max_caption_length = max(len(caption.split()) for caption in cleaned_captions) + 1

cnn_output_dim = inception_v3_model.output_shape[1] # 2048

batch_size_train = 270
batch_size_val = 150

train_data_generator = data_generator(train_captions, train_image_features, tokenizer, max_caption_length, batch_size_train)
val_data_generator = data_generator(val_captions, val_image_features, tokenizer, max_caption_length, batch_size_val)

# %%
def build_model(vocab_size, max_caption_length, cnn_output_dim):
    input_image = Input(shape=(cnn_output_dim,), name='Features_Input')
    fe1 = BatchNormalization()(input_image)
    fe2 = Dense(256, activation='relu')(fe1) # Adding a Dense layer to the CNN output to match the decoder output size
    fe3 = BatchNormalization()(fe2)

    input_caption = Input(shape=(max_caption_length,), name='Sequence_Input')
    se1 = Embedding(vocab_size, 256, mask_zero=True)(input_caption)
    se2 = LSTM(256, use_cudnn=False)(se1)

    decoder1 = add([fe3, se2])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax', name='Output_Layer')(decoder2)

    model = Model(inputs=[input_image, input_caption], outputs=outputs, name='Image_Captioning')
    return model

caption_model = build_model(vocab_size, max_caption_length, cnn_output_dim)

optimizer = Adam(learning_rate=0.01, clipnorm=1.0)
caption_model.compile(loss='categorical_crossentropy', optimizer=optimizer)

caption_model.summary()
# Out:
# Model: "Image_Captioning"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Features_Input      │ (None, 2048)      │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2048)      │      8,192 │ Features_Input[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Sequence_Input      │ (None, 34)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 256)       │    524,544 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 34, 256)   │  2,198,016 │ Sequence_Input[0… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ not_equal_2         │ (None, 34)        │          0 │ Sequence_Input[0… │
# │ (NotEqual)          │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256)       │      1,024 │ dense_4[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 256)       │    525,312 │ embedding_2[0][0… │
# │                     │                   │            │ not_equal_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256)       │          0 │ batch_normalizat… │
# │                     │                   │            │ lstm_2[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │     65,792 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ Output_Layer        │ (None, 8586)      │  2,206,602 │ dense_5[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 5,529,482 (21.09 MB)
#  Trainable params: 5,524,874 (21.08 MB)
#  Non-trainable params: 4,608 (18.00 KB)

# %%
plot_model(caption_model)

# %%
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

def lr_scheduler(epoch, lr):
    return lr * tf.math.exp(-0.6).numpy()

lr_schedule = LearningRateScheduler(lr_scheduler)

history = caption_model.fit(
    train_data_generator,
    steps_per_epoch=len(train_captions) // batch_size_train,
    validation_data=val_data_generator,
    validation_steps=len(val_captions) // batch_size_val,
    epochs=15,
    callbacks=[early_stopping, lr_schedule]
)
# Out:
# Epoch 1/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 474s 4s/step - loss: 4.6079 - val_loss: 3.7439 - learning_rate: 0.0030
# Epoch 2/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 111s 883ms/step - loss: 3.4339 - val_loss: 3.4361 - learning_rate: 0.0017
# Epoch 3/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 610ms/step - loss: 3.0676 - val_loss: 3.3575 - learning_rate: 9.0718e-04
# Epoch 4/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 80s 636ms/step - loss: 2.8727 - val_loss: 3.3155 - learning_rate: 4.9787e-04
# Epoch 5/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 607ms/step - loss: 2.7626 - val_loss: 3.2831 - learning_rate: 2.7324e-04
# Epoch 6/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 608ms/step - loss: 2.6919 - val_loss: 3.2746 - learning_rate: 1.4996e-04
# Epoch 7/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 81s 642ms/step - loss: 2.6521 - val_loss: 3.2783 - learning_rate: 8.2297e-05
# Epoch 8/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 76s 605ms/step - loss: 2.6240 - val_loss: 3.2808 - learning_rate: 4.5166e-05
# Epoch 9/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 613ms/step - loss: 2.6072 - val_loss: 3.2726 - learning_rate: 2.4788e-05
# Epoch 10/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 78s 619ms/step - loss: 2.6029 - val_loss: 3.2699 - learning_rate: 1.3604e-05
# Epoch 11/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 607ms/step - loss: 2.5953 - val_loss: 3.2801 - learning_rate: 7.4659e-06
# Epoch 12/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 607ms/step - loss: 2.5884 - val_loss: 3.2878 - learning_rate: 4.0973e-06
# Epoch 13/15
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 77s 607ms/step - loss: 2.5870 - val_loss: 3.2849 - learning_rate: 2.2487e-06

# %%
plt.figure(figsize=(15, 7), dpi=200)
sns.set_style('whitegrid')
plt.plot([x+1 for x in range(len(history.history['loss']))], history.history['loss'], color='#E74C3C', marker='o')
plt.plot([x+1 for x in range(len(history.history['loss']))], history.history['val_loss'], color='#641E16', marker='h')
plt.title('Train VS Validation', fontsize=15, fontweight='bold')
plt.xticks(fontweight='bold')
plt.yticks(fontweight='bold')
plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Loss', fontweight='bold')
plt.legend(['Train Loss', 'Validation Loss'], loc='best')
plt.show()

# %%
def greedy_generator(image_features):
    in_text = 'start '
    for _ in range(max_caption_length):
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        sequence = pad_sequences([sequence], maxlen=max_caption_length).reshape((1,max_caption_length))
        prediction = caption_model.predict([image_features.reshape(1,cnn_output_dim), sequence], verbose=0)
        idx = np.argmax(prediction)
        word = tokenizer.index_word[idx]
        in_text += ' ' + word
        if word == 'end':
            break

    in_text = in_text.replace('start ', '')
    in_text = in_text.replace(' end', '')

    return in_text

# %%
def beam_search_generator(image_features, K_beams = 3, log = False):
    start = [tokenizer.word_index['start']]
    start_word = [[start, 0.0]]
    for _ in range(max_caption_length):
        temp = []
        for s in start_word:
            sequence  = pad_sequences([s[0]], maxlen=max_caption_length).reshape((1,max_caption_length))
            preds = caption_model.predict([image_features.reshape(1,cnn_output_dim), sequence], verbose=0)
            word_preds = np.argsort(preds[0])[-K_beams:]
            for w in word_preds:
                next_cap, prob = s[0][:], s[1]
                next_cap.append(w)
                if log:
                    prob += np.log(preds[0][w]) # assign a probability to each K words
                else:
                    prob += preds[0][w]
                temp.append([next_cap, prob])

        start_word = temp
        start_word = sorted(start_word, reverse=False, key=lambda l: l[1])
        start_word = start_word[-K_beams:]

    start_word = start_word[-1][0]
    captions_ = [tokenizer.index_word[i] for i in start_word]
    final_caption = []
    for i in captions_:
        if i != 'end':
            final_caption.append(i)
        else:
            break

    final_caption = ' '.join(final_caption[1:])
    return final_caption

# %%
from nltk.translate.bleu_score import corpus_bleu

def BLEU_score(actual, greedy, beam_search):
    score_greedy_1 = corpus_bleu(actual, greedy, weights=(0.3, 0.3, 0.3, 0))
    score_greedy_2 = corpus_bleu(actual, greedy, weights=(0.25, 0.25, 0.25, 0.25))
    score_BS_1 = corpus_bleu(actual, beam_search, weights=(0.3, 0.3, 0.3, 0))
    score_BS_2 = corpus_bleu(actual, beam_search, weights=(0.25, 0.25, 0.25, 0.25))

    return [
        (f'BLEU-2 Greedy: {round(score_BS_2, 5)}'),
        (f'BLEU-1 Greedy: {round(score_BS_1, 5)}'),
        (f'Greedy: {greedy[0]}'),
        (f'BLEU-2 Beam Search: {round(score_greedy_2, 5)}'),
        (f'BLEU-1 Beam Search: {round(score_greedy_1, 5)}'),
        (f'Beam Search:  {beam_search[0]}')
    ]

# %%
generated_captions = {}

pbar = tqdm_notebook(total=len(test_image_features), position=0, leave=True, colour='green')
for image_id in test_image_features:
    cap = greedy_generator(test_image_features[image_id])
    generated_captions[image_id] = cap
    pbar.update(1)

pbar.close()
# Out:
#   0%|          | 0/122 [00:00<?, ?it/s]

# %%
test_actual_captions = {}
for caption in test_captions:
    image_id, caption_text = caption.split('\t')
    caption_text = caption_text.strip()
    if image_id not in test_actual_captions:
        test_actual_captions[image_id] = []
    test_actual_captions[image_id].append(caption_text)

# %%
def visualization(data, greedy_caps, beamS_generator, evaluator, num_of_images):
    keys = list(data.keys())
    images = [np.random.choice(keys) for i in range(num_of_images)] # Randomly selected images
    count = 1
    fig = plt.figure(figsize=(6,20))
    for filename in images:
        actual_cap = data[filename]
        actual_cap = [x.replace("start ", "") for x in actual_cap]
        actual_cap = [x.replace(" end", "") for x in actual_cap]

        greedy_cap = greedy_caps[filename]
        beamS_cap = beamS_generator(test_image_features[filename])

        caps_with_score = evaluator(actual_cap, [greedy_cap]*(len(actual_cap)), [beamS_cap]*(len(actual_cap)))

        image_load = load_img(images_directory+filename, target_size=(199,199,3))
        ax = fig.add_subplot(num_of_images,2,count,xticks=[],yticks=[])
        ax.imshow(image_load)
        count += 1

        ax = fig.add_subplot(num_of_images,2,count)
        plt.axis('off')
        ax.plot()
        ax.set_xlim(0,1)
        ax.set_ylim(0,len(caps_with_score))
        for i, text in enumerate(caps_with_score):
            ax.text(0,i,text,fontsize=10)
        count += 1
    plt.show()

visualization(test_actual_captions, generated_captions, beam_search_generator, BLEU_score, 7)

# %%
caption_model.save('caption_model.keras')

# %%
def inspect_model(model):
    """Inspects a Keras model and returns details about its layers."""
    model_details = []
    input_tensors = model.inputs # Get the input tensors
    for layer in model.layers:
        layer_details = {
            "Name": layer.name,
            "Type": layer.__class__.__name__,
            "Trainable": layer.trainable,
            "Parameters": layer.count_params(),
        }
        # For InputLayer, find the corresponding input tensor and get its shape
        if isinstance(layer, tf.keras.layers.InputLayer):
            # Find the input tensor with the same name as the input layer
            input_tensor = next((t for t in input_tensors if t.name.split('/')[0] == layer.name), None)
            if input_tensor is not None:
                layer_details["Shape"] = str(input_tensor.shape)
            else:
                layer_details["Shape"] = "N/A (Input Tensor Not Found)" # Should not happen in functional API
        else:
            # For other layers, get shape from output tensor
            if hasattr(layer, 'output') and tf.is_tensor(layer.output):
                 layer_details["Shape"] = str(layer.output.shape)
            elif isinstance(layer, tf.keras.layers.Layer): # Fallback for other Keras layers
                 try:
                     layer_details["Shape"] = str(layer.output_shape)
                 except AttributeError:
                     layer_details["Shape"] = "N/A (Shape not accessible)"
            else:
                 layer_details["Shape"] = "N/A (Not a Keras Layer or shape not accessible)"
        model_details.append(layer_details)
    return model_details

# Assuming 'caption_model' is your loaded or built model
model_details = inspect_model(caption_model)
for detail in model_details:
    print(detail)
# Out:
# {'Name': 'Features_Input', 'Type': 'InputLayer', 'Trainable': True, 'Parameters': 0, 'Shape': '(None, 2048)'}
# {'Name': 'batch_normalization_98', 'Type': 'BatchNormalization', 'Trainable': True, 'Parameters': 8192, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'Sequence_Input', 'Type': 'InputLayer', 'Trainable': True, 'Parameters': 0, 'Shape': '(None, 34)'}
# {'Name': 'dense_4', 'Type': 'Dense', 'Trainable': True, 'Parameters': 524544, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'embedding_2', 'Type': 'Embedding', 'Trainable': True, 'Parameters': 2198016, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'batch_normalization_99', 'Type': 'BatchNormalization', 'Trainable': True, 'Parameters': 1024, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'lstm_2', 'Type': 'LSTM', 'Trainable': True, 'Parameters': 525312, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'add_2', 'Type': 'Add', 'Trainable': True, 'Parameters': 0, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'dense_5', 'Type': 'Dense', 'Trainable': True, 'Parameters': 65792, 'Shape': 'N/A (Shape not accessible)'}
# {'Name': 'Output_Layer', 'Type': 'Dense', 'Trainable': True, 'Parameters': 2206602, 'Shape': 'N/A (Shape not accessible)'}

# %%
# Access the tokenizer object
# tokenizer is already available from cell 6Gng_-3ORbcL
print("Tokenizer object is available:", 'tokenizer' in globals())

# You can save the tokenizer to a file for use in your Streamlit app
import pickle

with open('tokenizer.pkl', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

print("Tokenizer saved to tokenizer.pkl")
# Out:
# Tokenizer object is available: True
# Tokenizer saved to tokenizer.pkl
